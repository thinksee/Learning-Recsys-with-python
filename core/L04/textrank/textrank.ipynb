# %%
from textrank4zh import TextRank4Keyword, TextRank4Sentence

text = '土耳其国防部9日晚宣布，土军队已对叙利亚北部的库尔德武装展开军事行动。分析人士认为，此次行动并非土方突然之举，而是其在美国宣布从叙相关区域撤军后的必然选项。行动能否实现土所期待的清除叙库尔德武装、解决叙难民安置问题难以预料。但可以确定的是，此举势必会给当地民众带来灾难，会给叙局势乃至地区局势带来严重影响。土国防部表示，作为“和平之泉”军事行动的一部分，土军队已开始在叙利亚北部幼发拉底河以东地区发动地面进攻。土总统埃尔多安当日在社交媒体上发布了军事行动开始的消息，称“和平之泉”军事行动的目的是防止库尔德“恐怖分子”在土南部边境线上建立起一道“恐怖主义走廊”，并促使叙利亚难民重返家园。长期以来，土耳其都视叙库尔德武装为恐怖组织，欲将其清除。但美国却视这一武装为反恐作战合作伙伴，这让土耳其在采取行动时颇有顾忌。美土于8月曾同意在叙东北部建立一个“安全区”，隔离土边境和叙东北部的库尔德武装力量，但两国在“安全区”的范围和管理等方面迟迟无法达成一致。'

tr4w = TextRank4Keyword()
tr4w.analyze(text=text, lower=True, window=2)
print('关键词：')
for item in tr4w.get_keywords(20, word_min_len=1):
    print(item.word, item.weight)

tr4s = TextRank4Sentence()
tr4s.analyze(text=text, lower=True, source='all_filters')
print('摘要：')
for item in tr4s.get_key_sentences(num=3):
    print(item.index, item.weight, item.sentence)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\thinksee\AppData\Local\Temp\jieba.cache
# Loading model cost 1.931 seconds.
# Prefix dict has been built successfully.
# 关键词：
# 土 0.042379195054714866
# 叙 0.039590539492346324
# 军事行动 0.02749413349232927
# 土耳其 0.023338347066152645
# 难民 0.02255149649387114
# 武装 0.02188669100703704
# 宣布 0.02155825665170464
# 美国 0.01893835927275734
# 人士 0.018865484735342414
# 安全区 0.018401768186738596
# 带来 0.0172058324374837
# 当日 0.01678404155184341
# 社交 0.016784041551843407
# 和平 0.016302507124455645
# 局势 0.016184022145912608
# 国防部 0.016132473667972203
# 能否 0.014758225625272913
# 走廊 0.01452798601585652
# 管理 0.014466391909541108
# 地面 0.01441900373174741
# 摘要：
# 5 0.13047221409423135 土总统埃尔多安当日在社交媒体上发布了军事行动开始的消息，称“和平之泉”军事行动的目的是防止库尔德“恐怖分子”在土南部边境线上建立起一道“恐怖主义走廊”，并促使叙利亚难民重返家园
# 0 0.12176046334244907 土耳其国防部9日晚宣布，土军队已对叙利亚北部的库尔德武装展开军事行动
# 2 0.12097306136967419 行动能否实现土所期待的清除叙库尔德武装、解决叙难民安置问题难以预料

# %%
import jieba
import jieba.analyse
import jieba.posseg as pseg

# %%
seg_list = jieba.cut(text, cut_all=False)

# %%
print(' '.join(seg_list))
# Out:
# 土耳其 国防部 9 日晚 宣布 ， 土 军队 已 对 叙利亚 北部 的 库尔德 武装 展开 军事行动 。 分析 人士 认为 ， 此次 行动 并非 土方 突然 之 举 ， 而是 其 在 美国 宣布 从 叙 相关 区域 撤军 后 的 必然 选项 。 行动 能否 实现 土所 期待 的 清除 叙 库尔德 武装 、 解决 叙 难民 安置 问题 难以预料 。 但 可以 确定 的 是 ， 此举 势必会 给 当地 民众 带来 灾难 ， 会 给 叙 局势 乃至 地区 局势 带来 严重 影响 。 土 国防部 表示 ， 作为 “ 和平 之泉 ” 军事行动 的 一部分 ， 土 军队 已 开始 在 叙利亚 北部 幼发拉底河 以东 地区 发动 地面 进攻 。 土 总统 埃 尔多 安 当日 在 社交 媒体 上 发布 了 军事行动 开始 的 消息 ， 称 “ 和平 之泉 ” 军事行动 的 目的 是 防止 库尔德 “ 恐怖分子 ” 在 土 南部 边境线 上 建立 起 一道 “ 恐怖主义 走廊 ” ， 并 促使 叙利亚 难民 重返家园 。 长期以来 ， 土耳其 都 视 叙 库尔德 武装 为 恐怖组织 ， 欲 将 其 清除 。 但 美国 却视 这 一 武装 为 反恐 作战 合作伙伴 ， 这 让 土耳其 在 采取行动 时 颇 有 顾忌 。 美土于 8 月 曾 同意 在 叙 东北部 建立 一个 “ 安全区 ” ， 隔离 土 边境 和 叙 东北部 的 库尔德 武装力量 ， 但 两国 在 “ 安全区 ” 的 范围 和 管理 等 方面 迟迟 无法 达成 一致 。

# %%
words = pseg.cut(sentence=text)

# %%
words
# Out:
# <generator object cut at 0x0000020FB6E57D48>

# %%
for word, flag in words:
    print('%s, %s' % (word, flag))
# Out:
# 土耳其, ns
# 国防部, nt
# 9, m
# 日晚, t
# 宣布, v
# ，, x
# 土, zg
# 军队, n
# 已, d
# 对, p
# 叙利亚, ns
# 北部, f
# 的, uj
# 库尔德, nrt
# 武装, n
# 展开, v
# 军事行动, n
# 。, x
# 分析, vn
# 人士, n
# 认为, v
# ，, x
# 此次, r
# 行动, vn
# 并非, c
# 土方, n
# 突然, ad
# 之, u
# 举, v
# ，, x
# 而是, c
# 其, r
# 在, p
# 美国, ns
# 宣布, v
# 从, p
# 叙, ns
# 相关, v
# 区域, n
# 撤军, v
# 后, f
# 的, uj
# 必然, d
# 选项, n
# 。, x
# 行动, vn
# 能否, v
# 实现, v
# 土所, n
# 期待, v
# 的, uj
# 清除, v
# 叙, ns
# 库尔德, nrt
# 武装, n
# 、, x
# 解决, v
# 叙, ns
# 难民, n
# 安置, v
# 问题, n
# 难以预料, l
# 。, x
# 但, c
# 可以, c
# 确定, v
# 的, uj
# 是, v
# ，, x
# 此举, r
# 势必会, n
# 给, p
# 当地, s
# 民众, n
# 带来, v
# 灾难, n
# ，, x
# 会, v
# 给, p
# 叙, ns
# 局势, n
# 乃至, c
# 地区, n
# 局势, n
# 带来, v
# 严重, a
# 影响, vn
# 。, x
# 土, zg
# 国防部, nt
# 表示, v
# ，, x
# 作为, v
# “, x
# 和平, nz
# 之泉, ns
# ”, x
# 军事行动, n
# 的, uj
# 一部分, m
# ，, x
# 土, zg
# 军队, n
# 已, d
# 开始, v
# 在, p
# 叙利亚, ns
# 北部, f
# 幼发拉底河, ns
# 以东, f
# 地区, n
# 发动, vn
# 地面, n
# 进攻, v
# 。, x
# 土, zg
# 总统, n
# 埃, ns
# 尔多, nrt
# 安, v
# 当日, t
# 在, p
# 社交, n
# 媒体, n
# 上, f
# 发布, v
# 了, ul
# 军事行动, n
# 开始, v
# 的, uj
# 消息, n
# ，, x
# 称, v
# “, x
# 和平, nz
# 之泉, ns
# ”, x
# 军事行动, n
# 的, uj
# 目的, n
# 是, v
# 防止, v
# 库尔德, nrt
# “, x
# 恐怖分子, n
# ”, x
# 在, p
# 土, n
# 南部, f
# 边境线, n
# 上, f
# 建立, v
# 起, v
# 一道, m
# “, x
# 恐怖主义, n
# 走廊, n
# ”, x
# ，, x
# 并, c
# 促使, v
# 叙利亚, ns
# 难民, n
# 重返家园, n
# 。, x
# 长期以来, l
# ，, x
# 土耳其, ns
# 都, d
# 视, vg
# 叙, v
# 库尔德, nrt
# 武装, n
# 为, p
# 恐怖组织, n
# ，, x
# 欲, d
# 将, d
# 其, r
# 清除, v
# 。, x
# 但, c
# 美国, ns
# 却视, v
# 这一, r
# 武装, n
# 为, p
# 反恐, v
# 作战, v
# 合作伙伴, n
# ，, x
# 这, r
# 让, v
# 土耳其, ns
# 在, p
# 采取行动, n
# 时, ng
# 颇, d
# 有, v
# 顾忌, nr
# 。, x
# 美, j
# 土, n
# 于, p
# 8, m
# 月, m
# 曾, d
# 同意, d
# 在, p
# 叙, ns
# 东北部, f
# 建立, v
# 一个, m
# “, x
# 安全区, j
# ”, x
# ，, x
# 隔离, v
# 土, zg
# 边境, n
# 和, c
# 叙, v
# 东北部, f
# 的, uj
# 库尔德, nrt
# 武装力量, l
# ，, x
# 但, c
# 两国, ns
# 在, p
# “, x
# 安全区, j
# ”, x
# 的, uj
# 范围, n
# 和, c
# 管理, vn
# 等, u
# 方面, n
# 迟迟, d
# 无法, n
# 达成, v
# 一致, d
# 。, x

# %%
keywords = jieba.analyse.extract_tags(sentence=text, topK=20, withWeight=True, allowPOS=('n', 'nr', 'ns'))

for item in keywords:
    print(item[0], item[1])
print('-'*100)
# Out:
# 军事行动 0.62277815012
# 武装 0.5038381794564286
# 叙利亚 0.4324142161269642
# 之泉 0.42695598224642856
# 土耳其 0.3980291865101786
# 难民 0.2899976477207143
# 局势 0.26437126794642857
# 重返家园 0.23584875841785716
# 土所 0.21347799112321428
# 军队 0.20358533541749999
# 恐怖组织 0.1998683473375
# 边境线 0.193029199975
# 恐怖分子 0.1852556629892857
# 土方 0.17699452866803572
# 幼发拉底河 0.1745275583380357
# 恐怖主义 0.17341112339196427
# 社交 0.16709612267339286
# 采取行动 0.16214993011374998
# 顾忌 0.16200649847624998
# 势必会 0.16130612859857144
# ----------------------------------------------------------------------------------------------------

# %%
## 基于TextRank算法的关键词抽取
keywords = jieba.analyse.textrank(sentence=text, topK=20, withWeight=True, allowPOS=('n', 'ns')) 
print(keywords)
# Out:
# [('军事行动', 1.0), ('武装', 0.8141535484617882), ('叙利亚', 0.8012974928650104), ('民众', 0.5575006141331473), ('方面', 0.5550352319840866), ('地区', 0.53876675074484), ('难民', 0.5263562388924751), ('土耳其', 0.4533372623809788), ('之泉', 0.41529971829951806), ('局势', 0.4110728944793326), ('地面', 0.3914747296863938), ('重返家园', 0.39087070215755465), ('走廊', 0.37831491673223394), ('恐怖主义', 0.37559240883756584), ('幼发拉底河', 0.35403745555141336), ('媒体', 0.35191256711248275), ('合作伙伴', 0.29133860808540807), ('目的', 0.2903408966033359), ('灾难', 0.28853716437059784), ('范围', 0.2874893769572471)]

# %%
keywords = jieba.analyse.extract_tags(text, topK=20, withWeight=True, allowPOS=('n','nr','ns'))
print(keywords)
# Out:
# [('军事行动', 0.62277815012), ('武装', 0.5038381794564286), ('叙利亚', 0.4324142161269642), ('之泉', 0.42695598224642856), ('土耳其', 0.3980291865101786), ('难民', 0.2899976477207143), ('局势', 0.26437126794642857), ('重返家园', 0.23584875841785716), ('土所', 0.21347799112321428), ('军队', 0.20358533541749999), ('恐怖组织', 0.1998683473375), ('边境线', 0.193029199975), ('恐怖分子', 0.1852556629892857), ('土方', 0.17699452866803572), ('幼发拉底河', 0.1745275583380357), ('恐怖主义', 0.17341112339196427), ('社交', 0.16709612267339286), ('采取行动', 0.16214993011374998), ('顾忌', 0.16200649847624998), ('势必会', 0.16130612859857144)]

# %%
keywords = jieba.analyse.textrank(text, topK=20, withWeight=True, allowPOS=('ns', 'n', 'vn', 'v'))
print(keywords)
# Out:
# [('军事行动', 1.0), ('武装', 0.9578814503128161), ('叙利亚', 0.6525054966070027), ('地区', 0.6399458163221615), ('行动', 0.59609466802699), ('带来', 0.5695007968185084), ('难民', 0.5523770626076563), ('局势', 0.5006980786387909), ('方面', 0.4855382308188176), ('开始', 0.4625002954124787), ('清除', 0.4282951129251396), ('实现', 0.4236302191491501), ('宣布', 0.41577070060281013), ('地面', 0.3901444761117219), ('美国', 0.3856627360986961), ('土耳其', 0.381007355567177), ('管理', 0.37265656432183414), ('幼发拉底河', 0.3711076274092414), ('无法', 0.37104773625696996), ('建立', 0.3706696912770231)]

# %%
keywords = jieba.analyse.textrank(text, topK=20, withWeight=True) 
print(keywords)
# Out:
# [('军事行动', 1.0), ('武装', 0.9578814503128161), ('叙利亚', 0.6525054966070027), ('地区', 0.6399458163221615), ('行动', 0.59609466802699), ('带来', 0.5695007968185084), ('难民', 0.5523770626076563), ('局势', 0.5006980786387909), ('方面', 0.4855382308188176), ('开始', 0.4625002954124787), ('清除', 0.4282951129251396), ('实现', 0.4236302191491501), ('宣布', 0.41577070060281013), ('地面', 0.3901444761117219), ('美国', 0.3856627360986961), ('土耳其', 0.381007355567177), ('管理', 0.37265656432183414), ('幼发拉底河', 0.3711076274092414), ('无法', 0.37104773625696996), ('建立', 0.3706696912770231)]
