# %% [markdown]
# ## football
# [python-igraph manual](https://igraph.org/python/doc/tutorial/tutorial.html)
#
# [https://stackoverflow.com/questions/12072093/python-igraph-plotting-not-available](https://stackoverflow.com/questions/12072093/python-igraph-plotting-not-available)

# %%
import igraph

# %%
g = igraph.Graph.Read_GML('./football.gml')
igraph.plot(g)
print(g.community_label_propagation())
# Out:
# Clustering with 115 elements and 12 clusters
# [ 0] 0, 4, 9, 16, 23, 41, 93, 104
# [ 1] 1, 25, 33, 37, 45, 89, 103, 105, 109
# [ 2] 2, 6, 13, 15, 32, 39, 47, 60, 64, 100, 106
# [ 3] 3, 5, 10, 11, 24, 28, 40, 50, 52, 69, 72, 74, 81, 84, 90, 97, 98, 102,
#      107
# [ 4] 7, 8, 21, 22, 51, 68, 77, 78, 108, 111
# [ 5] 12, 14, 26, 36, 38, 42, 43, 85
# [ 6] 17, 20, 27, 56, 62, 65, 70, 76, 87, 95, 96, 113
# [ 7] 18, 31, 34, 54, 61, 71, 99
# [ 8] 19, 29, 30, 35, 55, 79, 80, 82, 94, 101
# [ 9] 44, 48, 57, 66, 75, 86, 91, 92, 112
# [10] 46, 49, 53, 67, 73, 83, 88, 110, 114
# [11] 58, 59, 63

# %%
import networkx as nx
from networkx.algorithms import community
import matplotlib.pyplot as plt

# 数据加载
G=nx.read_gml('./football.gml')
# 可视化
nx.draw(G,with_labels=True) 
plt.show()
# 社区发现
communities = list(community.label_propagation_communities(G))
print(communities)
print(len(communities))
# Out:
# [{'BowlingGreenState', 'Buffalo', 'Kent', 'Ohio', 'MiamiOhio', 'Akron', 'Connecticut', 'Marshall'}, {'Navy', 'Syracuse', 'WestVirginia', 'MiamiFlorida', 'Temple', 'BostonCollege', 'Pittsburgh', 'Rutgers', 'NotreDame', 'VirginiaTech'}, {'AirForce', 'ColoradoState', 'NevadaLasVegas', 'NewMexico', 'BrighamYoung', 'Utah', 'Wyoming', 'SanDiegoState'}, {'Purdue', 'MichiganState', 'Illinois', 'OhioState', 'Wisconsin', 'Michigan', 'Iowa', 'Minnesota', 'Indiana', 'Northwestern', 'PennState'}, {'KansasState', 'Colorado', 'Texas', 'Oklahoma', 'TexasA&M', 'IowaState', 'Nebraska', 'Missouri', 'TexasTech', 'OklahomaState', 'Baylor', 'Kansas'}, {'WakeForest', 'Duke', 'GeorgiaTech', 'FloridaState', 'Clemson', 'NorthCarolina', 'Maryland', 'NorthCarolinaState', 'Virginia'}, {'UCLA', 'BoiseState', 'NorthTexas', 'NewMexicoState', 'Washington', 'California', 'SouthernCalifornia', 'ArizonaState', 'WashingtonState', 'Stanford', 'UtahState', 'Oregon', 'Arizona', 'Idaho', 'OregonState', 'ArkansasState'}, {'A
# ...
