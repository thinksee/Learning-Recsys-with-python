# %%
import pandas as pd
import networkx as nx  # https://networkx.github.io/documentation/stable/tutorial.html
import numpy as np
from collections import defaultdict # dict factory
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## PageRank-networkx

# %%
# 创建有向图
G = nx.DiGraph()   
# 设置有向图的边集合
edges = [("A", "B"), ("A", "C"), ("A", "D"), ("B", "A"), ("B", "D"), ("C", "A"), ("D", "B"), ("D", "C")]
# 在有向图G中添加边集合
for edge in edges:
    G.add_edge(edge[0], edge[1])

# %%
# 有向图可视化
layout = nx.spring_layout(G)
nx.draw(G, pos=layout, with_labels=True, hold=False)
plt.show()

# %%
# 计算简化模型的PR值
pr = nx.pagerank(G, alpha=1)
print("简化模型的PR值：", pr)
# 计算随机模型的PR值
pr = nx.pagerank(G, alpha=0.8)
print("随机模型的PR值：", pr)
# Out:
# 简化模型的PR值： {'A': 0.33333396911621094, 'B': 0.22222201029459634, 'C': 0.22222201029459634, 'D': 0.22222201029459634}
# 随机模型的PR值： {'A': 0.3214290507775999, 'B': 0.22619031640746662, 'C': 0.22619031640746662, 'D': 0.22619031640746662}

# %% [markdown]
# ## PageRank-Email

# %%
emails = pd.read_csv('Emails.csv')

# %%
emails.head(2)
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#   MetadataTo       MetadataFrom  SenderPersonId           MetadataDateSent  \
# 0          H  Sullivan, Jacob J            87.0  2012-09-12T04:00:00+00:00
# 1          H                NaN             NaN  2011-03-03T05:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# 1  2015-05-22T04:00:00+00:00
#
#                                      MetadataPdfLink MetadataCaseNumber  ...  \
# 0  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841  ...
# 1  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841  ...
#
#   ExtractedTo                             ExtractedFrom ExtractedCc  \
# 0         NaN  Sullivan, Jacob J <Sullivan11@state.gov>         NaN
# 1         NaN                                       NaN         NaN
#
#                         ExtractedDateSent ExtractedCaseNumber  \
# 0  Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 1                                     NaN        F-2015-04841
#
#   ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 0          C05739545            05/13/2015              RELEASE IN FULL
# 1          C05739546            05/13/2015              RELEASE IN PART
#
#                                    ExtractedBodyText  \
# 0                                                NaN
# 1  B6\r\nThursday, March 3, 2011 9:45 PM\r\nH: La...
#
#                                              RawText
# 0  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
# 1  UNCLASSIFIED\r\nU.S. Department of State\r\nCa...
#
# [2 rows x 22 columns]

# %%
emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
# Id                              7945 non-null int64
# DocNumber                       7945 non-null object
# MetadataSubject                 7649 non-null object
# MetadataTo                      7690 non-null object
# MetadataFrom                    7788 non-null object
# SenderPersonId                  7788 non-null float64
# MetadataDateSent                7813 non-null object
# MetadataDateReleased            7945 non-null object
# MetadataPdfLink                 7945 non-null object
# MetadataCaseNumber              7945 non-null object
# MetadataDocumentClass           7945 non-null object
# ExtractedSubject                6260 non-null object
# ExtractedTo                     3288 non-null object
# ExtractedFrom                   6692 non-null object
# ExtractedCc                     2640 non-null object
# ExtractedDateSent               6628 non-null object
# ExtractedCaseNumber             7944 non-null object
# ExtractedDocNumber              7944 non-null object
# ExtractedDateReleased           7944 non-null object
# ExtractedReleaseInPartOrFull    7945 non-null object
# ExtractedBodyText               6742 non-null object
# RawText                         7945 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.3+ MB

# %%
aliases = pd.read_csv('Aliases.csv')

# %%
aliases.head(2)
# Out:
#    Id                         Alias  PersonId
# 0   1                111th congress         1
# 1   2  agna usemb kabul afghanistan         2

# %%
aliases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 3 columns):
# Id          850 non-null int64
# Alias       850 non-null object
# PersonId    850 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 20.0+ KB

# %%
# 利用aliases数据集建立Alias<->PersonId之间的映射
aliases_personid = {}
for index, row in aliases.iterrows():
    aliases_personid[row['Alias']] = row['PersonId']

# %%
aliases_personid
# Out:
# {'111th congress': 1,
#  'agna usemb kabul afghanistan': 2,
#  'ap': 3,
#  'asuncion': 4,
#  'alec': 5,
#  'dupuy alex': 6,
#  'american beverage association': 7,
#  'mayock andrew': 8,
#  'shapiro andrew j': 9,
#  'shapiroa@state.gov': 9,
#  'slaughter annmarie': 10,
#  'slaughter anne marie': 10,
#  'slaughter annemarie': 10,
#  'slaughtera@state.gov': 10,
#  'lake anthony': 11,
#  'valenzuela arturo a': 12,
#  'valenzuelaaa@state.gov': 12,
#  'kimoon ban': 13,
#  'obama barack': 14,
#  'president': 14,
#  'bam@mikulski.senate.gov': 15,
#  'mikulski bam': 15,
#  'mikulski bam (mikulski)': 15,
#  'mikulski bam (mitkulski)': 15,
#  'mikulskibam (mikulski)': 15,
#  'betsy.ebeling': 16,
#  'ebeling betsy': 16,
#  'betsyebeling': 16,
#  'betsyebeling1050': 16,
#  'clinton william j': 17,
#  'dad': 17,
#  'biography': 18,
#  'klehr bonnie': 19,
#  'brian': 20,
#  'bstrider': 21,
#  'strider burns': 21,
#  'capricia marshall': 22,
#  'marshall capricia': 22,
#  'marshall capricia p': 22,
#  'capriciamarshall': 22,
#  'capriciamarshall@': 22,
#  'cmarshall': 22,
#  'marshallcp@state.gov': 22,
#  'pascual carlos': 23,
#  'adler caroline e': 24,
#  'button case': 25,
#  'richards cecile': 26,
#  'eur/rus:weson chad': 27,
#  'nea/pi/ce:kiamie charles': 28,
#  'chelsea': 29,
#  'blair cherie': 30,
#  'cherie blair': 30,
#  'cb': 30,
#  'cherieblair': 30,
#  'cheryl': 31,
#  'c:mills cheryl': 32,
#  'cheryl mills': 32,
#  'cheryl mills cos': 32,
#  'mill cheryl': 32,
#  'mills cherlyl d': 32,
#  'mills chery d': 32,
#  'mills cheryl': 32,
#  'mills cheryl d': 32,
#  'millscheryl d': 32,
#  'mills. cherl d': 32,
#  'mills. cheryl d': 32,
#  'millscd@state.gov': 32,
#  'cheryl.mills': 32,
#  'cheryl.mills@': 32,
#  'crocker chester a': 33,
#  'butzgy christopher h': 34,
#  'edwards christopher': 35,
#  'eap/j:green christopher': 36,
#  'hill christopher r (baghdad)': 37,
#  'hillcr@state.gov': 37,
#  'coleman claire l': 38,
#  'colin powell': 39,
#  'council on foreign relations': 40,
#  'beale courtney a karamer': 41,
#  'beale courtney a kramer': 41,
#  'bealeca@state.gov': 41,
#  'kelly craig a': 42,
#  'daily sun': 43,
#  'hyde dana': 44,
#  'daniel': 45,
#  'baer daniel': 46,
#  'baer daniel b': 46,
#  'baer daniel d': 46,
#  'baer.daniel': 46,
#  'daniel.baer': 46,
#  'inonye daniel': 47,
#  'schwerin daniel b': 48,
#  'schwerindb@state.gov': 48,
#  'brian danielle': 49,
#  'axelrod david m': 50,
#  'axelrod_d': 50,
#  'brock david': 51,
#  'david_garten@lautenberg.senate.gov': 52,
#  'garten david (lautenberg)': 52,
#  'inl:johnson david t': 53,
#  'd.gunners2010': 54,
#  'department of state': 55,
#  'chollet derek h': 56,
#  'cholletdh@state.gov': 56,
#  'reynolds diane': 57,
#  'donald': 58,
#  'band doug': 59,
#  'hattaway doug': 60,
#  'doug': 60,
#  'pelton e': 61,
#  'politico  drew elizabeth': 62,
#  'tauscher ellen o': 63,
#  'tauschereo@state.gov': 63,
#  'faleomavaega eni f': 64,
#  'woodard eric w': 65,
#  'brimmer esther d': 66,
#  'brimmere@state.gov': 66,
#  'finca international': 67,
#  'foreign affairs magazine': 68,
#  'prm/mce:wills g': 69,
#  'lou de bac g/tip': 70,
#  'prm/mce:willsg': 71,
#  'mitchell george': 72,
#  'glantz gina': 73,
#  'glantz.': 73,
#  'govenman etazini': 74,
#  'haiti': 75,
#  'duksoo han': 76,
#  'koh harold hongju': 77,
#  'kohhh@state.gov': 77,
#  'heintz': 78,
#  'hill': 79,
#  'hillary clinton': 80,
#  'clinton': 80,
#  'clinton hillary r': 80,
#  'clinton hillary': 80,
#  'clinton hillary rodham': 80,
#  'h': 80,
#  'h2': 80,
#  'hrc': 80,
#  'hillary': 80,
#  'hillary rodham clinton': 80,
#  'madam secretary': 80,
#  'secretary': 80,
#  'secretary clinton': 80,
#  'secretary of state': 80,
#  'hr15@mycingular.blackberry.net': 80,
#  'hrod17@clintonemail.com': 80,
#  'the honorable hillary rodham clinton secretary of state': 80,
#  'hdr22@clintonemail.com': 80,
#  'abedin huma': 81,
#  'abedinh@state.gov': 81,
#  'abein huma': 81,
#  'abendin huma': 81,
#  'adedin huma': 81,
#  'huma abedin': 81,
#  'huma@clintonemail.com': 81,
#  'abedin@state.gov': 81,
#  'abendinh@state.gov': 81,
#  'adedinh@state.gov': 81,
#  'kelly ian': 82,
#  'ds/pa:finkle j': 83,
#  'jama': 84,
#  'newmyer jackie': 85,
#  'newmyer': 85,
#  'lew': 86,
#  'lew jacob': 86,
#  'lew jacob j': 86,
#  'jacobjlew': 86,
#  'lewjj@state.gov': 86,
#  'sullivan jj@state.gov': 87,
#  'sullivan jacbo j': 87,
#  'sullivan jack': 87,
#  'sullivan jacob': 87,
#  'sullivan jacob h': 87,
#  'sullivan jacob j': 87,
#  'sullivan jake': 87,
#  'sullivan jake j': 87,
#  'sullivanjj@state.gov': 87,
#  'jake. sullivan': 87,
#  'jake.sullivan': 87,
#  'jake.sullivan@': 87,
#  'sulllivanjj@state.gov': 87,
#  'sullivanil@state.gov': 87,
#  'sullivann@state.gov.': 87,
#  'mcgovern james p': 88,
#  'smith james e': 89,
#  'steinberg james b': 90,
#  'steinbergjb@state.gov': 90,
#  'steinbertjb@state.gov': 90,
#  'jpiercy': 91,
#  'jacobs janice l': 92,
#  'farrow jeffrey': 93,
#  'farrow jeffrey l': 93,
#  'jfarrow': 93,
#  'feltman jeffrey d': 94,
#  'feltmanjd@state.gov': 94,
#  'robinson jennifer': 95,
#  'hoagland jim': 96,
#  'kennedy jim': 97,
#  'laszczych joanne': 98,
#  'olver john': 99,
#  'podesta john': 100,
#  'jpodesta': 100,
#  'carson johnnie': 101,
#  'carsonj@state.gov': 101,
#  'jonathan prince': 102,
#  'daniel joshua j': 103,
#  'kieffer judith': 104,
#  'mchale judith': 105,
#  'mchale judith a': 105,
#  'mchaleja@state.gov': 105,
#  'cooper justin': 106,
#  'kpk': 107,
#  'kabul lgf request': 108,
#  'eikenberry karl w': 109,
#  'kellyc@state.gov': 110,
#  'conrad kent': 111,
#  'baldersonkm@state.gov': 112,
#  'balderston kris m': 112,
#  'balderstone kris m': 112,
#  'balderstonkm@state.gov': 112,
#  'campbell kurt m': 113,
#  'campbellkm@state.gov': 113,
#  'eap/k:rosenberger l': 114,
#  'lgraham': 115,
#  'jilloty lauren c': 116,
#  'jiloty cheryl d': 116,
#  'jiloty lauren': 116,
#  'jiloty lauren c': 116,
#  'jiloty lauren cd': 116,
#  'jiloty. lauren c': 116,
#  'jilotylc@state.gov': 116,
#  'jjiloty lauren c': 116,
#  'jjilotylc@state.gov': 116,
#  'lauren jiloty': 116,
#  'rubiner laurie': 117,
#  'brown lee r': 118,
#  'feinstein lee': 119,
#  'dewan linda l': 120,
#  'captuol': 121,
#  'caputol': 121,
#  'imuscatine': 122,
#  'lissa muscatine': 122,
#  'muscantine lissa': 122,
#  'muscatine lissa': 122,
#  'muscatine lisa': 122,
#  'muscatinelissa': 122,
#  'muscatine. lissa': 122,
#  'muscatinel@state.gov': 122,
#  'lmuscatine': 122,
#  'muscantinel@state.gov': 122,
#  'quam lois': 123,
#  'valmmorolj@state.gov': 124,
#  'valmoro lona': 124,
#  'valmoro lona j': 124,
#  'valmoroli@state.gov': 124,
#  'valmorolj@state.gov': 124,
#  'walmoro lona j': 124,
#  'long term strategy group': 125,
#  'diamond louise': 126,
#  'cue lourdes c': 127,
#  'g/tip:cdebaca luis': 128,
#  'luzzatto': 129,
#  'lynn': 130,
#  'albright m k': 131,
#  'albright madeleine': 132,
#  'williamsbarrett': 133,
#  'calivis maria': 134,
#  'otero maria': 135,
#  'oterom2@state.gov': 135,
#  'af/pdpa:scott marianne': 136,
#  'mark': 137,
#  'markjpenn': 138,
#  'mtorrey': 139,
#  'eca:pally maura': 140,
#  'pally maura m': 140,
#  'baucus max': 141,
#  'rooney megan': 142,
#  'pverveer': 143,
#  'vereer melanne s': 143,
#  'verveer melanne e': 143,
#  'verveer melanne s': 143,
#  'verveerms@state.gov': 143,
#  'fuchs michael h': 144,
#  'fuchsmh@state.gov': 144,
#  'posner michael h': 145,
#  'posnermh@state.gov': 145,
#  'bond michele t': 146,
#  'michele.flournoy': 147,
#  'rodriguez miguel e': 148,
#  'mike': 149,
#  'hanley monica r': 150,
#  'hanleymr@state.gov': 150,
#  'nhla': 151,
#  'nancy': 152,
#  'neera tanden': 153,
#  'tandem neera': 153,
#  'tanden neera': 153,
#  'ntanden': 153,
#  'new york times': 154,
#  'norman nicholas': 155,
#  'toiv nora f': 156,
#  'toivnf@state.gov': 156,
#  'tov nora f': 157,
#  'opinion research': 158,
#  'sanchez oscar arias': 159,
#  'flores oscar': 160,
#  'lores oscar': 161,
#  'pvervee': 162,
#  'kennedy patrick f': 163,
#  'm:kennedy patrick f': 163,
#  'collier paul': 164,
#  'jones paul w': 165,
#  'nea/ipa:knopf payton': 166,
#  'robinson peter': 167,
#  'crowley philip': 168,
#  'crowley philip j': 168,
#  'gordon philip h': 169,
#  'gordon. philip h': 169,
#  'gordonph@state.gov': 169,
#  'pir': 170,
#  'reines philipe i': 170,
#  'reines philippe': 170,
#  'reines philippe i': 170,
#  'reines phillippe i': 170,
#  'rines philippe i': 170,
#  'preines': 170,
#  'reines@state.gov': 170,
#  'reinesp@state.gov': 170,
#  'crowley phillip j': 171,
#  'crowleypj@state.gov': 171,
#  'campbell piper': 172,
#  'prime minister': 173,
#  'shah rajiv': 174,
#  'rshah': 174,
#  'recos': 175,
#  'philippe reines': 176,
#  'preval rene': 177,
#  'lewis reta jo': 178,
#  'holbrookerc@state.gov': 179,
#  'verma richard': 180,
#  'verma richard r': 180,
#  'vermarr@state.gov': 180,
#  'rsloan': 181,
#  'blake robert o': 182,
#  'danford robert a': 183,
#  'hormats robert d': 184,
#  'hormatsrd@state.gov': 184,
#  'russo robert  v': 185,
#  'russo robert v': 185,
#  'russorv@state.gov': 185,
#  'rodriguezme@state.gov': 186,
#  'howe rosemarie': 187,
#  'rosemarie.howe': 187,
#  'zaidi s akbar': 188,
#  's/srgia': 189,
#  'state': 190,
#  'berger samuel r': 191,
#  'sberger': 191,
#  'sandy': 191,
#  'berger samuel': 192,
#  'sgration': 193,
#  'blumenthal sidney': 194,
#  'sid': 194,
#  'sbwhoeop': 194,
#  'sbwhoeop@': 194,
#  'sbwhoop': 194,
#  'sir': 195,
#  'talbott strobe': 196,
#  'stalbott': 196,
#  'stallbott': 196,
#  'rice susan e': 197,
#  'rice susan e.': 197,
#  'grantham suzanne l': 198,
#  'terry.duffy': 199,
#  'donilon thomas e': 200,
#  'nides thomas r': 201,
#  'nidestr@state.gov': 201,
#  'shannon thomas a': 202,
#  'wha: shannon thomas a': 202,
#  'shannonta@state.gov': 202,
#  'tflourno': 203,
#  'stern todd': 204,
#  'stern todd d': 204,
#  'stern todd d (s/secc)': 204,
#  'sterntd@state.gov': 204,
#  'tillemann tomicah': 205,
#  'tillemann tomicah s': 205,
#  'tillemannts@state.gov': 205,
#  'elbegdori tsakina': 206,
#  'u.s. global leadership coalition': 207,
#  'estados unidos da america': 208,
#  'estados unidos de norteamerica': 208,
#  'etatunis damerique': 208,
#  'etatsunis damerique': 208,
#  'united states of america': 208,
#  'nuland victoria j': 209,
#  'ebeling voda': 210,
#  'ebelling voda': 210,
#  'whadp': 211,
#  'washington post': 212,
#  'sherman wendy': 213,
#  'sherman wendy r': 213,
#  'wsherman': 213,
#  'ilic werner x': 214,
#  'white house': 215,
#  'burns william j': 216,
#  'burnswj@state.gov': 216,
#  'wburns': 216,
#  'wburns66': 216,
#  'wburns66@': 216,
#  'hubbard william': 217,
#  'iscol zachary': 218,
#  'aclb': 219,
#  'alcb': 220,
#  'l': 221,
#  'latimes.com': 222,
#  'mh.interiors': 223,
#  'mhcaleja@state.gov': 224,
#  'postmaster@state.gov': 225,
#  'rooneym@state.gov': 226,
#  'rrh.interiors': 227,
#  'b6': 228,
#  'sullivan jacob 1': 87,
#  'mills cheryl 0': 32,
#  'nuiand victoria j': 229,
#  'reines philippe f': 230,
#  'sullivan jacob j nuland victoria 1': 231,
#  'sullivan jacobi': 87,
#  'russorv@stategov': 232,
#  'sullivan jacob .1 ‹sullivann@state.gov>': 87,
#  'sullivan jacob i': 87,
#  'burns strider': 21,
#  'mcdonough denis r. (mailto: b6': 87,
#  'sullivan jacob .1': 87,
#  'abeclin huma': 81,
#  'oscar flores': 233,
#  'milts cheryl 0': 32,
#  'sidney blumenthal': 194,
#  'su ii iva gll@state.gov.': 234,
#  'annemarie slaughter': 10,
#  'sullivahu@state.gov': 235,
#  'barton rick (cso)': 32,
#  'mills cheryl id': 32,
#  'russoiv@state.gov': 236,
#  'miliscd@stategov': 237,
#  'sullivan jacob 3': 87,
#  'abedin hume': 81,
#  'hanky monica r': 150,
#  'h ehrod17@clintonemailcom>': 80,
#  'abedinh@stategov': 238,
#  'lvlills cheryl d': 32,
#  'tomlinson christina b3 cia pers/org': 32,
#  'h ‹hrod17@clintonernail.com>': 80,
#  'tanleyrnr@state.gov': 239,
#  'hanleymr@stategov': 240,
#  'hanley monica r .': 150,
#  'sullivan jacob.)': 87,
#  'hemmen chris': 32,
#  'rnillscd@state.gov': 241,
#  'sullivan jacob .‹suilivan1j©st.ate.gov>': 87,
#  'rnillscd@stategov.': 242,
#  'sullivanjj@state.gov.': 243,
#  'mills chey 0': 32,
#  'reiriesp@state.gov': 244,
#  'sidney blumenthal b6': 194,
#  'suilivanii@stategov': 245,
#  'sullivanj@state.gov': 246,
#  'suilivanij@state.gok': 247,
#  'hanleymr@state.gov.': 248,
#  'reines philippe t': 249,
#  'hanleyrnr@state.gov': 250,
#  'h 1': 80,
#  'hanieymr@state.gov': 251,
#  'mills. cheryl 0': 32,
#  'hanleymrgastategov': 252,
#  'sulliyanfostate.gott': 253,
#  'aliilscd@state.gov': 254,
#  'sullivan jacob j esullivanii@stategov>': 87,
#  'mills cheryl d :miliscd@stategov>': 32,
#  'mills cheryl d [mailto:millscd@stategovi': 80,
#  'mills cheryl d [mailto:millscd©state.gov]': 80,
#  'valmoro lona j ‹valmorou c stategov>': 124,
#  'valnnoro lona j': 124,
#  'mills cheryl 0emillscd@state.gov>': 32,
#  'nidesth@stategoy': 255,
#  'bums william j': 216,
#  'h ‹hrod17@clintonemailcom>': 80,
#  'millscd@state.gov.': 256,
#  'jacob j sullivan': 257,
#  'reines philippe)': 170,
#  'sullivan jacobj': 87,
#  'jake sullivan _': 87,
#  'sullivanji@state.gov': 258,
#  'stevens john c': 87,
#  'sullivanjj@state.golt': 259,
#  'millscd@state.goy': 260,
#  'nulandyj@state.goy': 261,
#  'sulliyanij@state.goy': 262,
#  'rnillscd@state.govs': 263,
#  'nuland victoria 3': 209,
#  'jake.sullivar': 264,
#  'jilotylc@state.gov.': 265,
#  'jake.sulliyan': 266,
#  'michele.fl': 267,
#  'cheryimills millscd@state.gov': 268,
#  'jake.sulliva': 269,
#  'valmoroll@state.gov.': 270,
#  'habedin b6': 271,
#  'valmorou@state.gov': 272,
#  'filotylc@state.gov': 273,
#  'habedin': 274,
#  'cheryl.mills jake.sullivan': 275,
#  'abedinh@state.gov.': 276,
#  'millscd@state.aov': 277,
#  'illotylc@state.gov': 278,
#  'millscd@state ov': 279,
#  'habedin(': 280,
#  'doug band': 281,
#  'sullivanij@state.gov.': 282,
#  'preines@': 283,
#  'abedinh  state ov': 284,
#  'cheryl.mills abedinh@state.gov': 285,
#  'cheryl.mill': 286,
#  'briar': 287,
#  'abedinh@state.goy': 288,
#  'a bedinh@state.gov': 289,
#  'preine': 290,
#  'valmorol.1@state.gov': 291,
#  'sullivanij@state.gov': 292,
#  'preines sullivanjj@state.gov b6': 293,
#  'valmorolj@state.gov.': 294,
#  'leltmanjd@state.gov': 295,
#  'ullivanjj@state.gov': 296,
#  'sta i bott': 297,
#  'sullivanjj©state ov': 298,
#  'millscd@state.00v.': 299,
#  'steinbergib@state.gov': 300,
#  'cheryl.millf.': 301,
#  'mhcaleja@state.gove': 302,
#  'cheryl.millsi': 303,
#  's abedinh@state.gov': 304,
#  'valmorou@state.gov.': 305,
#  'chetyl.mills sullivanij@state.gov': 306,
#  'sullivanu@state.gov.': 307,
#  'muscatinel@state.goy': 308,
#  'preines  sullivanjj@state.gov': 309,
#  'axelrod_': 310,
#  'wburns6': 311,
#  'valmorol1@state.gov.': 312,
#  'steinberg1b@state.gov': 313,
#  '. huma abedin': 314,
#  'abedinh@stategovl': 315,
#  'valmorou©state.gov': 316,
#  'reinesp@state.goy': 317,
#  'sulliyanjj@state.goy': 318,
#  'emillscd@state.gov': 319,
#  'cheryl.mill sullivanjj@state.gov': 320,
#  'cheryl.mills millscd@state.gov.': 321,
#  'preines verveerms@state.gov': 322,
#  'jilotylc@state.goy': 323,
#  'val moro u@state.gov': 324,
#  'a bed inh@state.gov': 325,
#  'mot lc@state.gov': 326,
#  'jilot lc@state. ov': 327,
#  '.1ilotylc@state.gov.': 328,
#  'iilotylc@state.gov.': 329,
#  'jilotylc©state.gov.': 330,
#  'cheryl.mills sullivanjj@state.gov': 331,
#  'iewjj@state.gov': 332,
#  'cheryl.mills _': 333,
#  'sulliva njj@state.g ov': 334,
#  'pverveel': 335,
#  '. h': 80,
#  'preines sullivanij@state.gov.': 336,
#  'sta ibott': 337,
#  'balderstonkm@state.gov.': 338,
#  '11': 80,
#  'rossdb@state.gov': 339,
#  'bowens': 340,
#  'jacobjlev': 341,
#  'yeryeerms@state.goy': 342,
#  'preines b6': 343,
#  'valmorou@state.gove': 344,
#  'abedinh@state.gove': 345,
#  'campbelikm@state.gov': 346,
#  'nancy millscd@state.gov b6': 347,
#  'valmorou©state.gov.': 348,
#  'andy manatos': 80,
#  'vanbuskirk michael 1': 349,
#  'huma abed in': 350,
#  'caputo': 351,
#  '.gordonph@state.gov.': 352,
#  'preines sullivanjj@state.gov': 353,
#  'cheryl.mills sullivanjj@state.gov b6': 354,
#  'cheryl.mills( sullivanjj@state.gov': 355,
#  'huma abedin b6': 356,
#  'mtorrey1': 357,
#  'glantz.gina': 358,
#  'millscd@tate.gov': 359,
#  'cheryl.mills huma abedin': 360,
#  'cheryl.mills millscd@state.gov': 361,
#  'campbelikm©state.gov': 362,
#  'jacobjlew vermarr@state.gov': 363,
#  'sullivanjj@state.gov b6': 364,
#  'iilotylc@state.gov': 365,
#  'rnillscd@state.gov.': 366,
#  'sullivanjj@state.govr': 367,
#  'lewij@state.gov': 368,
#  'williamsbarrett millscd@state.gov.': 369,
#  'abedinh©state.gov': 370,
#  's sullivanjj@state.gov': 371,
#  'filotylc@state.gov.': 372,
#  '..lilotylc@state.gov.': 373,
#  'baer.danie': 374,
#  'reines philippe i (pace)': 170,
#  'mills.cheryl d': 32,
#  'millscd@state.ov': 375,
#  'cmills': 376,
#  'newmyer on behalf of jackie newmyer': 85,
#  'cheryl mills[': 32,
#  'otero mildred (clinton)': 377,
#  'iewij@state.gov': 378,
#  'abed in huma': 81,
#  'jake sullivan': 87,
#  'preines huma abedin': 379,
#  'h.': 80,
#  'ieltmanjd@state.gov.': 380,
#  'valmoroll@state.gov': 381,
#  'h [mailto:hdr22@clintonemail.com]': 32,
#  'ben kobren': 80,
#  'todd stern': 382,
#  'jonespw2@state.gov.': 383,
#  'daniel.baer@': 384,
#  'jonespw2@state.gov': 385,
#  'cmarshal': 386,
#  'sbwhoeop b6': 387,
#  'jackie newmyer': 85,
#  'pverveer b6': 143,
#  'cheryl.mill abedin huma': 388,
#  'lee feinstein': 119,
#  'cheryl.mills b6': 32,
#  'strobe talbott': 196,
#  'berger samuel r.': 191,
#  'abedin hurna': 81,
#  'abed in hu ma': 81,
#  'jeffrey l farrow': 93,
#  'pvervee _': 143,
#  'jeffrey farrow': 93,
#  'eizenstat stuart': 32,
#  'valmoro lona j walmorou@state.goy>': 124,
#  'lew jacob i': 389,
#  'steinberg james': 390,
#  'rosemarie.howe h': 391,
#  'abedin hu ma': 81,
#  'sbwhoeor': 194,
#  'esullivanjj@state.gov': 392,
#  'cheryl.miils@ millscd@state.gov': 393,
#  'millscd©state.gov': 394,
#  'justin cooper': 395,
#  'strobe talbott b6': 196,
#  'valmoro lona 1': 124,
#  'axelrod david m.': 50,
#  'john podesta': 100,
#  'eabedinh@state.gov': 396,
#  'abedinh@state.govr': 397,
#  'cheryl.mills@ millscd@state.gov.': 398,
#  'williamsbarre0': 399,
#  'lissa muscatine b6': 122,
#  'minyon moore .': 32,
#  'capricia penavic marshall': 400,
#  'maggie williams': 401,
#  'rosemarie howe': 402,
#  'valmoro lona j walmorou@state.gov>': 124,
#  'lewjj@state.gov.': 403,
#  'wendy sherman': 213,
#  'jim kennedy': 404,
#  'jake.sullivan(': 87,
#  'choilet derek h': 56,
#  'cdm': 405,
#  'axelrod david m. b6': 50,
#  'wburns66 b6 i': 216,
#  'donilon thomas e.': 200,
#  'jacob lew': 86,
#  'lou de baca g/tip': 70,
#  '* abedin huma': 81,
#  'pj': 406,
#  'crowleyp  state ov. preines': 407,
#  'hume abedin': 408,
#  'valmoro lona1': 124,
#  'marciel scot a': 409,
#  '0 mills cheryl d': 32,
#  '.': 410,
#  'smith daniel b': 411,
#  'il': 412,
#  'cheryl.mill1': 413,
#  'jpier4': 414,
#  'berger samuel r. b6': 191,
#  'sbwhoeopc': 194,
#  'sullivanii@state.govr': 415,
#  'holbrooke richard c': 416,
#  'verveer melanne s werveerms@state.gov>': 143,
#  'cheryl.millsc': 32,
#  'm.k albright': 131,
#  'tauscher ellen 0': 63,
#  'jake sullivar': 87,
#  'gina glantz b6': 73,
#  'voda ebeling': 210,
#  'abedin huma eabedinh@state.gov>': 81,
#  'lew jacob 1': 86,
#  'sbwhoeop b61': 194,
#  'info@mailva.evite.com': 81,
#  'luzzatt': 417,
#  'daniel baer': 46,
#  'reta jo lewis special representative global intergovernmental affairs': 178,
#  'daniel.bae': 418,
#  'valmorou state. ov': 419,
#  'vanbuskirk michael .3': 420,
#  'edwards christopher (jakarta/pro)': 421,
#  'merten kenneth h': 32,
#  'preine h': 422,
#  'preines h': 423,
#  'shah rajiv (aid/a)': 174,
#  'sbwhoeor.': 194,
#  'williamsbarret': 424,
#  'sullivanii@state.gov': 425,
#  'hannah richert': 426,
#  'ross alec j': 427,
#  'sbwhoecip': 194,
#  'sbwhoeopi': 428,
#  '. sullivan jacobi': 87,
#  'betsyebelin': 16,
#  'sbwhoeor b6': 194,
#  'doua band': 429,
#  'daniel meron': 180,
#  'adams david s': 430,
#  'doug hattaway': 431,
#  'mills; cheryl d': 32,
#  'colby cooper': 81,
#  'kritenbrink daniel j': 432,
#  'cheryl mills b6': 32,
#  'abdinh@state.gov': 433,
#  'fareed zein': 32,
#  'sawsanhassan1': 434,
#  'stanton katie': 435,
#  'h b6': 436,
#  'blake robert 0': 182,
#  'irussorv@state.gov': 437,
#  'valmoro lona .1': 438,
#  'valmorol1@state.gov': 439,
#  'valmorou@state.goy': 440,
#  'valmdrou@state.gov': 441,
#  'dimartino kitty': 442,
#  'waxman sharon l': 443,
#  'jcooper': 444,
#  'lgraham doug band': 445,
#  'jai:e sullivan': 446,
#  'crowley philip 1': 168,
#  'crowley philip1': 168,
#  'sullivanii@state.gov.': 447,
#  'hume abed in': 448,
#  'sbvvhoeop': 194,
#  'berniertoth michelle': 449,
#  'coley theodore r': 450,
#  'c — cheryl mills': 32,
#  'rice susan e (usun)': 197,
#  'bonnie klehr': 451,
#  'ramamurthy': 452,
#  'h i': 453,
#  'eichensehr kristen e': 454,
#  'hooke kathleen h': 455,
#  'johnson clifton m': 456,
#  'tones susan': 457,
#  'townley stephen g': 458,
#  'torres susan': 459,
#  'abedinhuma': 81,
#  'evergreen': 460,
#  'lona valmoro': 461,
#  'fl': 462,
#  'elaine weiss': 463,
#  'kevin m. okeefe': 464,
#  'michael m. conway': 465,
#  'lew jacobi': 466,
#  'hai': 467,
#  'holbrooke richard': 87,
#  'harris jennifer m': 468,
#  'p1r': 170,
#  'pcharron': 469,
#  'zachary iscol': 218,
#  'jiloty lauren c dilotylc@state.gov>': 116,
#  'preine5': 470,
#  'samuel berger': 192,
#  'laurenjiloty jilotylc@state.gov': 471,
#  'laurenjiloty': 472,
#  'ian1evqr@state.gov': 473,
#  'jake sullivan b6': 87,
#  'woodardew@state.gov': 474,
#  'sullivan jacob)': 87,
#  'rshal': 475,
#  'megan rooney': 142,
#  'millscd@state. ov': 476,
#  'jacobjle iewjj@state.gov b6': 477,
#  'declan kelly': 478,
#  'jake.sullivan b6': 87,
#  'steinberg1b@state.gov.': 479,
#  'jake.sullivan h': 480,
#  'ogordonph@state.gov.': 481,
#  'crowley @state.  ov': 482,
#  'sbwhoeo': 483,
#  'steven.everts': 80,
#  'sullivanij@state.gove': 484,
#  'p rei n es': 485,
#  'imuscatine huma abedin b6': 486,
#  'tillemannts@state.gov.': 487,
#  'sullivan jacob1': 87,
#  'markjpenr': 488,
#  'dad mom': 489,
#  'vaimorou@state.gov': 490,
#  'prein6': 491,
#  'sullivanjj@state.goy': 492,
#  '. vermarr@state.gov': 493,
#  'sullivanjj@siate.gov': 494,
#  'rina amiri': 87,
#  'feldman daniel f': 495,
#  'ruggiero frank 3': 496,
#  'singh vikram': 497,
#  '.filotylc@state.gov.': 498,
#  'h hrod17@clintonemail.com>': 80,
#  'bstrider mmoore': 499,
#  '.1ilotylc@state.gov': 500,
#  'abed inh@state.gov.': 501,
#  'burns strider b6': 21,
#  'jon davidson': 502,
#  'aclb b6': 220,
#  'iynn': 503,
#  'a bed in h@state.gov': 504,
#  'sullivan jacob.': 87,
#  'scott gration': 87,
#  's_specialassistants': 505,
#  'jake.sullivar preines': 506,
#  'david brock': 51,
#  'lanny j. davis': 72,
#  'capriciamarshall huma abedin': 507,
#  'jilotylc©state.gov': 508,
#  'marshallcp@state.goy': 509,
#  'sid blumenthal': 510,
#  'monica.hanle': 511,
#  'hanle mr@state.gov': 512,
#  'ha nleym r@state.gov': 513}

# %%
persons = pd.read_csv('Persons.csv')

# %%
persons.head(2)
# Out:
#    Id                          Name
# 0   1                111th Congress
# 1   2  AGNA USEMB Kabul Afghanistan

# %%
id_name = {}  # 建立Id-Name之间的映射关系
for index, row in persons.iterrows():
    id_name[row['Id']] = row['Name']

# %%
# 利用数据集Aliases和Persons进行aliases和name之间的转换
def unify_aliase(alise):
    alise = str(alise).lower()  # 小写
    alise = alise.replace(',','').split('@')[0]  # 先去掉',',再按照'@'进行切割
    if alise in aliases_personid.keys():
        return id_name[aliases_personid[alise]]
    return alise

# %%
# 图可视化
def show_graph(graph, layout_type='spring_layout'):
    if layout_type == 'spring_layout':  # 类似中心放射状
        positions = nx.spring_layout(graph)
    elif layout_type == 'circular_layout':  # 在一个圆环上均匀分布
        positions = nx.circular_layout(graph)
    else:
        raise NameError(layout_type, "isn't define.")
    
    # 设置网络图中的节点大小，大小与pagerank值相关，因为pagerank值很小所以需要*20000
    nodesize = [x['pagerank']*20000 for v,x in graph.nodes(data=True)]
    # 设置网络图中的边长度
    edgesize = [np.sqrt(e[2]['weight']) for e in graph.edges(data=True)]
    # 绘制节点
    nx.draw_networkx_nodes(graph, positions, node_size=nodesize, alpha=0.4)
    # 绘制边
    nx.draw_networkx_edges(graph, positions, edge_size=edgesize, alpha=0.2)
    # 绘制节点的label
    nx.draw_networkx_labels(graph, positions, font_size=10)
    # 输出希拉里邮件中的所有人物关系图
    plt.show()

# %%
emails.MetadataFrom = emails.MetadataFrom.apply(unify_aliase)
emails.MetadataTo = emails.MetadataTo.apply(unify_aliase)

# %%
emails.MetadataTo
# Out:
# 0       Hillary Clinton
# 1       Hillary Clinton
# 2                    ;h
# 3       Hillary Clinton
# 4           Huma Abedin
#              ...
# 7940    Hillary Clinton
# 7941    Hillary Clinton
# 7942    Hillary Clinton
# 7943    Hillary Clinton
# 7944    Hillary Clinton
# Name: MetadataTo, Length: 7945, dtype: object

# %%
# 设置权重为发邮件的次数
edges_weights_temp = defaultdict(list)
for row in zip(emails.MetadataFrom, emails.MetadataTo):
    temp = (row[0], row[1])
    if temp not in edges_weights_temp:
        edges_weights_temp[temp] = 1
    else:
        edges_weights_temp[temp] += 1
edges_weights_temp
# Out:
# defaultdict(list,
#             {('Jake Sullivan', 'Hillary Clinton'): 815,
#              ('nan', 'Hillary Clinton'): 20,
#              ('Cheryl Mills', ';h'): 1,
#              ('Cheryl Mills', 'Hillary Clinton'): 1182,
#              ('Hillary Clinton', 'Huma Abedin'): 32,
#              ('Hillary Clinton', 'russorv'): 26,
#              ('slaughter anne-marie', 'Hillary Clinton'): 126,
#              ('Harold Hongju Koh', 'Hillary Clinton'): 12,
#              ('Wendy Sherman', 'Hillary Clinton'): 7,
#              ('Jake Sullivan', 'Wendy Sherman'): 1,
#              ('Hillary Clinton', 'sullivanjj'): 288,
#              ('Sidney Blumenthal', 'Hillary Clinton'): 361,
#              ('Burns Strider', 'Hillary Clinton'): 2,
#              ('Huma Abedin', 'Hillary Clinton'): 1322,
#              ('Cheryl Mills', 'Cheryl Mills'): 17,
#              ('Robert Russo', 'Hillary Clinton'): 22,
#              ('Capricia Marshall', 'Cheryl Mills'): 2,
#              ('Hillary Clinton', 'Oscar Flores'): 5,
#              ('William Burns', 'Hillary Clinton'): 10,
#              ('Monica Hanley', 'Hillary Clinton'): 24,
#              ('Hillary Clinton', 'abedinh'): 345,
#              ('Hillary Clinton', 'millscd'): 298,
#              ('Daniel Schwerin', 'Hillary Clinton'): 9,
#              ('Hillary Clinton', 'hanleymr'): 33,
#              ('Monica Hanley', 'Daniel Schwerin'): 1,
#              ('Philippe Reines', 'Thomas Nides'): 1,
#              ('Daniel Schwerin', 'Jake Sullivan'): 1,
#              ('nan', 'nan'): 132,
#              ('Hillary Clinton', 'jilotylc'): 226,
#              ('Melanne Verveer', 'Hillary Clinton'): 94,
#              ('Hillary Clinton', 'nan'): 42,
#              ('Claire Coleman', 'Hillary Clinton'): 5,
#              ('Philippe Reines', 'Hillary Clinton'): 144,
#              ('Cheryl Mills', 'Jake Sullivan'): 7,
#              ('Philippe Reines', 'Cheryl Mills'): 1,
#              ('Monica Hanley', 'Jake Sullivan'): 1,
#              ('Lona Valmoro', 'Hillary Clinton'): 136,
#              ('Hillary Clinton', 'valmorolj'): 131,
#              ('Hillary Clinton', 'burnswj'): 5,
#              ('Thomas Nides', 'Hillary Clinton'): 1,
#              ('Hillary Clinton', 'nidestr'): 1,
#              ('Hillary Clinton', 'Jake Sullivan'): 15,
#              ('Victoria Nuland', 'Hillary Clinton'): 1,
#              ('Maria Otero', 'Hillary Clinton'): 9,
#              ('Judith McHale', 'Hillary Clinton'): 68,
#              ('Hillary Clinton', 'Michele Flournoy'): 1,
#              ('Hillary Clinton', 'Cheryl Mills'): 40,
#              ('hrod17', 'Jake Sullivan'): 2,
#              ('Alec', 'Cheryl'): 1,
#              ('Hillary Clinton', 'Philippe Reines'): 49,
#              ('Hillary Clinton', 'Brian Greenspun'): 1,
#              ('Hillary Clinton', 'reinesp'): 12,
#              ('Hillary Clinton', 'bam'): 4,
#              ('Hillary Clinton', 'l'): 1,
#              ('hrod17', 'Philippe Reines'): 2,
#              ('Hillary Clinton', 'Neera Tanden'): 2,
#              ('hrod17', 'valmorolj'): 8,
#              ('Hillary Clinton', 'Jacob Lew'): 3,
#              ('Hillary Clinton', 'Rick Sloan'): 1,
#              ('Hillary Clinton', 'Strobe Talbott'): 11,
#              ('Hillary Clinton', 'balderstonkm'): 16,
#              ('Hillary Clinton', 'steinbergjb'): 8,
#              ('Hillary Clinton', 'William Burns'): 2,
#              ('Hillary Clinton', 'mhcaleja'): 1,
#              ('Hillary Clinton', 'John Podesta'): 2,
#              ('Hillary Clinton', 'sulllivanjj'): 4,
#              ('Hillary Clinton', 'Wendy Sherman'): 2,
#              ('Hillary Clinton', 'abendinh'): 1,
#              ('Hillary Clinton', 'adedinh'): 1,
#              ('hrod17', 'nan'): 2,
#              ('Hillary Clinton', 'Lissa Muscatine'): 7,
#              ('Hillary Clinton', 'muscatinel'): 15,
#              ('hrod17', 'muscatinel'): 3,
#              ('hrod17', 'sullivanjj'): 9,
#              ('hrod17', 'cholletdh'): 1,
#              ('hrod17', 'Huma Abedin'): 3,
#              ('hrod17', 'Burns Strider'): 1,
#              ('Hillary Clinton', 'Jeffrey Farrow'): 1,
#              ('Hillary Clinton', 'David Axelrod'): 1,
#              ('Hillary Clinton', 'Samuel ("Sandy") Berger'): 3,
#              ('Hillary Clinton', 'shapiroa'): 6,
#              ('Hillary Clinton', 'david_garten'): 2,
#              ('hrod17', 'millscd'): 14,
#              ('hrod17', 'reinesp'): 1,
#              ('Hillary Clinton', 'verveerms'): 9,
#              ('Hillary Clinton', 'kohhh'): 3,
#              ('Hillary Clinton', 'lewjj'): 7,
#              ('Hillary Clinton', 'Sidney Blumenthal'): 49,
#              ('Hillary Clinton', 'Tina Flournoy'): 1,
#              ('Hillary Clinton', 'Cherie Blair'): 7,
#              ('Hillary Clinton', 'Melanne Verveer'): 10,
#              ('Hillary Clinton', 'Jan Piercy'): 1,
#              ('Hillary Clinton', 'fuchsmh'): 4,
#              ('Hillary Clinton', 'Capricia Marshall'): 6,
#              ('Hillary Clinton', 'Terry Duffy'): 1,
#              ('hrod17', 'jilotylc'): 7,
#              ('Hillary Clinton', 'crowleypj'): 10,
#              ('Hillary Clinton', 'campbellkm'): 9,
#              ('Hillary Clinton', 'rooneym'): 6,
#              ('E. Pelton', 'nan'): 1,
#              ('Charles Kiamie', 'nan'): 3,
#              ('hrod17', 'abedinh'): 5,
#              ('hrod17', 'Scott Gration'): 1,
#              ('Hillary Clinton', 'Doug Hattaway'): 4,
#              ('Hillary Clinton', 'Nancy Parrish'): 1,
#              ('Hillary Clinton', 'kellyc'): 3,
#              ('Hillary Clinton', 'holbrookerc'): 1,
#              ('hrod17', 'Lisa Caputo'): 1,
#              ('hrod17', 'gordonph'): 1,
#              ('Hillary Clinton', 'Lisa Caputo'): 1,
#              ('Hillary Clinton', 'slaughtera'): 29,
#              ('Nicholas Norman', 'nan'): 1,
#              ('Hillary Clinton', 'rodriguezme'): 4,
#              ('Hillary Clinton', 'Marty Torrey'): 2,
#              ('Hillary Clinton', 'Gina Glantz'): 1,
#              ('Hillary Clinton', 'Maggie Williams'): 3,
#              ('Hillary Clinton', 'hillcr'): 1,
#              ('hrod17', 'verveerms'): 1,
#              ('Hillary Clinton', 'tauschereo'): 3,
#              ('Hillary Clinton', 'feltmanjd'): 3,
#              ('Hillary Clinton', 'gordonph'): 3,
#              ('hrod17', 'Daniel Baer'): 1,
#              ('Hillary Clinton', 'steinbertjb'): 1,
#              ('Claire Coleman', 'Cheryl Mills'): 1,
#              ('Lauren Jiloty', 'Hillary Clinton'): 312,
#              ('millscd', 'Hillary Clinton'): 61,
#              ('Cheryl Mills', 'Lourdes Cue'): 1,
#              ('Jake Sullivan', 'Cheryl Mills'): 4,
#              ('Neera Tanden', 'Hillary Clinton'): 6,
#              ('James Steinberg', 'Hillary Clinton'): 6,
#              ('Cherie Blair', 'Hillary Clinton'): 24,
#              ('Hillary Clinton', 'valmoroli'): 1,
#              ('Hillary Clinton', 'vermarr'): 27,
#              ('Thomas Shannon', 'Hillary Clinton'): 2,
#              ('Lauren Jiloty', 'Huma Abedin'): 5,
#              ('Jackie Newmyer', 'Hillary Clinton'): 10,
#              ('Barbara Mikulski', 'Hillary Clinton'): 11,
#              ('Patrick Kennedy', 'Hillary Clinton'): 1,
#              ('nan', 'Hill'): 1,
#              ('Robert Danford', 'Hillary Clinton'): 1,
#              ('Cheryl Mills', 'Huma Abedin'): 13,
#              ('Huma Abedin', 'Cheryl Mills'): 5,
#              ('Lissa Muscatine', 'Hillary Clinton'): 80,
#              ('NHLA', 'nan'): 1,
#              ('Hillary Clinton', 'carsonj'): 1,
#              ('Cheryl Mills', 'Capricia Marshall'): 1,
#              ('Jacob Lew', 'nan'): 1,
#              ('Hillary Clinton', 'shannonta'): 1,
#              ('abedinh', 'Hillary Clinton'): 46,
#              ('Hillary Clinton', 'Luzzatto'): 1,
#              ('Hillary Clinton', 'Daniel Baer'): 1,
#              ('Long Term Strategy Group', 'Department of State'): 1,
#              ('Hillary Clinton', 'marshallcp'): 3,
#              ('millscd', 'Jake Sullivan'): 1,
#              ('G. Wills', 'nan'): 2,
#              ('reinesp', 'Hillary Clinton'): 2,
#              ('Strobe Talbott', 'Hillary Clinton'): 35,
#              ('David Johnson', 'Jacob Lew'): 2,
#              ('Philippe Reines', 'Jake Sullivan'): 3,
#              ('L. Rosenberger', 'nan'): 1,
#              ('Lee Brown', 'Karl Eikenberry'): 2,
#              ('Lee Feinstein', 'Hillary Clinton'): 1,
#              ('Samuel ("Sandy") Berger', 'Hillary Clinton'): 8,
#              ('FINCA International', 'nan'): 1,
#              ('Huma Abedin', 'Rosemarie Howe'): 3,
#              ('Cherie Blair', 'hr15'): 1,
#              ('slaughter anne-marie', 'nan'): 1,
#              ('valmorolj', 'Hillary Clinton'): 5,
#              ('White House', 'nan'): 1,
#              ('Jeffrey Farrow', 'Hillary Clinton'): 6,
#              ('Jake Sullivan', 'Strobe Talbott'): 1,
#              ('Kris Balderston', 'Hillary Clinton'): 22,
#              ('Richard Verma', 'Hillary Clinton'): 115,
#              ('postmaster', 'Hillary Clinton'): 7,
#              ('Colin Powell', 'Hillary Clinton'): 1,
#              ('Huma Abedin', 'Donald'): 1,
#              ('Cheryl Mills', 'Phillip Crowley'): 1,
#              ('Lona Valmoro', 'Huma Abedin'): 10,
#              ('Huma Abedin', 'Richard Verma'): 2,
#              ('Huma Abedin', 'rosemarie.howe ;h'): 1,
#              ('Cheryl Mills', 'Rene Preval'): 1,
#              ('hrod17', 'vermarr'): 3,
#              ('Huma Abedin', 'Mark Hyman'): 2,
#              ('Hillary Clinton', 'hormatsrd'): 1,
#              ('Sidney Blumenthal', 'cheryl.mills ;h'): 1,
#              ('Cheryl Mills', 'Justin Cooper'): 1,
#              ('Oscar Arias Sanchez', 'nan'): 1,
#              ('Hillary Clinton', 'sterntd'): 3,
#              ('Kurt Campbell', 'Hillary Clinton'): 14,
#              ('David Axelrod', 'Hillary Clinton'): 2,
#              ('Hillary Clinton', 'abedin'): 1,
#              ('John Podesta', 'Hillary Clinton'): 2,
#              ('Jake Sullivan', 'Philippe Reines'): 7,
#              ('David Garten', 'Hillary Clinton'): 1,
#              ('Caroline Adler', 'Hillary Clinton'): 2,
#              ('Cheryl Mills', 'Maggie Williams'): 2,
#              ('sullivanjj', 'Huma Abedin'): 1,
#              ('Huma Abedin', 'Lona Valmoro'): 2,
#              ('Huma Abedin', 'Jake Sullivan'): 7,
#              ('bam', 'Hillary Clinton'): 1,
#              ('Hillary Clinton', 'posnermh'): 1,
#              ('Cheryl Mills', 'nan'): 3,
#              ('muscatinel', 'Hillary Clinton'): 1,
#              ('abedinh', 'rrh.interiors'): 1,
#              ('Hillary Clinton', 'Council on Foreign Relations'): 1,
#              ('Sidney Blumenthal', 'Cheryl Mills'): 1,
#              ('Cheryl Mills', 'Jacob Lew'): 3,
#              ('111th Congress', 'nan'): 1,
#              ('Hillary Clinton', 'schwerindb'): 1,
#              ('Huma Abedin', 'mh.interiors'): 1,
#              ('Cheryl Mills', 'Jim Kennedy'): 1,
#              ('Cheryl Mills', 'Samuel ("Sandy") Berger'): 1,
#              ('Cheryl Mills', 'Strobe Talbott'): 1,
#              ('sullivanjj', 'Hillary Clinton'): 22,
#              ('abedinh', 'Cheryl Mills'): 2,
#              ('nan', 'Biography'): 1,
#              ('Andrew Shapiro', 'Hillary Clinton'): 7,
#              ('verveerms', 'Hillary Clinton'): 1,
#              ('Derek Chollet', 'Hillary Clinton'): 1,
#              ('Jeffrey Farrow', 'Jake Sullivan'): 4,
#              ('reines philippe ', 'Hillary Clinton'): 1,
#              ('Thomas Donilon', 'Hillary Clinton'): 1,
#              ('Jacob Lew', 'Hillary Clinton'): 12,
#              ('G. Lou de Bac', 'Cheryl Mills'): 1,
#              ('Huma Abedin', 'Huma Abedin'): 1,
#              ('Laurie Rubiner', 'Hillary Clinton'): 1,
#              ('Huma Abedin', 'Laurie Rubiner'): 1,
#              ('verveerms', 'Huma Abedin'): 1,
#              ('Huma Abedin', 'Oscar Flores'): 12,
#              ('Danielle Brian', 'Hillary Clinton'): 2,
#              ('Strobe Talbott', 'nan'): 1,
#              ('Werner Ilic', 'Kabul LGF Request'): 1,
#              ('nan', 'Sir'): 1,
#              ('crowleypj', 'h;preines'): 2,
#              ('Jeffrey Feltman', 'Hillary Clinton'): 13,
#              ('PVervee', 'Hillary Clinton'): 1,
#              ('Philip Crowley', 'Hillary Clinton'): 15,
#              ('George Mitchell', 'Hillary Clinton'): 6,
#              ('AGNA USEMB Kabul Afghanistan', 'nan'): 1,
#              ('Huma Abedin', 'valmorolj'): 5,
#              ('Philippe Reines', 'Huma Abedin'): 1,
#              ('Huma Abedin', 'jilotylc'): 1,
#              ('J. Finkle', 'nan'): 1,
#              ('Capricia Marshall', 'Hillary Clinton'): 12,
#              ('Capricia Marshall', 'Huma Abedin'): 1,
#              ('Michael Fuchs', 'Hillary Clinton'): 15,
#              ('Capricia Marshall', 'abedin huma; h'): 2,
#              ('Hillary Clinton', 'ki-moon ban'): 1,
#              ('Prime Minister', 'Peter Robinson'): 1,
#              ('Ian Kelly', 'nan'): 1,
#              ('STATE', 'ASUNCION'): 1,
#              ('STATE', 'WHADP'): 1,
#              ('Lissa Muscatine', 'Huma Abedin'): 1,
#              ('Sidney Blumenthal', 'nan'): 11,
#              ('Eni Faleomavaega', 'nan'): 1,
#              ('Cheryl Mills', 'Lona Valmoro'): 1,
#              ('Lona Valmoro', 'Cheryl Mills'): 1,
#              ('Susan Rice', 'nan'): 1,
#              ('Paul Jones', 'Hillary Clinton'): 2,
#              ('Philip Gordon', 'Hillary Clinton'): 4,
#              ('h; mills cheryl d', 'Kris Balderston'): 1,
#              ('Philippe Reines', 'Philip Crowley'): 1,
#              ('Miguel Rodriguez', 'Hillary Clinton'): 10,
#              ('Christopher Hill', 'Hillary Clinton'): 1,
#              ('politico - drew elizabeth', 'nan'): 1,
#              ('Cheryl Mills', 'Lauren Jiloty'): 1,
#              ('Lauren Jiloty', 'Cheryl Mills'): 3,
#              ('U.S. Global Leadership Coalition', 'nan'): 1,
#              ('M. Albright', 'Hillary Clinton'): 1,
#              ('Max Baucus', 'Hillary Clinton'): 1,
#              ('Linda Dewan', 'Hillary Clinton'): 1,
#              ('jilotylc', 'Hillary Clinton'): 21,
#              ('Ellen Tauscher', 'Hillary Clinton'): 9,
#              ('Gina Glantz', 'Hillary Clinton'): 2,
#              ('Voda Ebeling', 'Lauren Jiloty'): 1,
#              ('Patrick Kennedy', 'nan'): 1,
#              ('Arturo Valenzuela', 'Hillary Clinton'): 7,
#              ('Nora Tov', 'Hillary Clinton'): 1,
#              ('Philippe Reines', 'Diane Reynolds'): 2,
#              ('Huma Abedin', 'Luzzatto'): 1,
#              ('Daniel Baer', 'Hillary Clinton'): 5,
#              ('SRGIA', 'nan'): 1,
#              ('Jeffrey Feltman', 'Harold Hongju Koh'): 2,
#              ('Harold Hongju Koh', 'Jeffrey Feltman'): 1,
#              ('Reta Jo Lewis', 'Hillary Clinton'): 1,
#              ('Johnnie Carson', 'Hillary Clinton'): 1,
#              ('sullivan jj', 'Hillary Clinton'): 2,
#              ('Huma Abedin', 'sullivanjj'): 1,
#              ('muscatinel', 'Daniel Baer'): 1,
#              ('Nora Toiv', 'Hillary Clinton'): 5,
#              ('KPK', 'Hillary Clinton'): 1,
#              ('Robert Russo', 'Doug Hattaway'): 1,
#              ('Cheryl Mills', 'Christopher Edwards'): 1,
#              ('Cheryl Mills', 'Maura Pally'): 1,
#              ('mchaleja', 'Hillary Clinton'): 3,
#              ('millscd', 'Nora Toiv'): 1,
#              ('Todd Stern', 'Hillary Clinton'): 5,
#              ('Jake Sullivan', 'preines; h'): 1,
#              ('Philippe Reines', 'sullivan jake; h'): 1,
#              ('vermarr', 'Hillary Clinton'): 2,
#              ('Huma Abedin', 'preines; h'): 1,
#              ('Rajiv Shah', 'Hillary Clinton'): 1,
#              ('Judith McHale', 'Lona Valmoro'): 1,
#              ('Huma Abedin', 'Oscar Lores'): 1,
#              ('Christopher Green', 'nan'): 1,
#              ('Robert Hormats', 'Hillary Clinton'): 1,
#              ('Chad Weston', 'nan'): 1,
#              ('Strobe Talbott', 'Huma Abedin'): 1,
#              ('valmorolj', 'Huma Abedin'): 1,
#              ('Michael Posner', 'Hillary Clinton'): 1,
#              ('Cecile Richards', 'nan'): 1,
#              ('Philip Crowley', 'Michael Posner'): 1,
#              ('Andrew Mayock', 'nan'): 1,
#              ('Washington Post', 'nan'): 4,
#              ('Jim Hoagland', 'nan'): 1,
#              ('Tomicah Tillemann', 'nan'): 1,
#              ('slaughtera', 'Hillary Clinton'): 3,
#              ('lewjj', 'Hillary Clinton'): 1,
#              ('Haiti', 'United States of America'): 3,
#              ('nan', "etats-unis d'amerique"): 1,
#              ('Haiti', "etat-unis d'amerique"): 1,
#              ('Huma Abedin', 'Justin Cooper'): 1,
#              ('Jake Sullivan', 'Philip Crowley'): 1,
#              ('Jake Sullivan', 'Richard Verma'): 2,
#              ('Cheryl Mills', 'Michele Bond'): 1,
#              ('vermarr', 'Jake Sullivan'): 1,
#              ('Betsy Ebeling', 'Hillary Clinton'): 30,
#              ('Payton Knopf', 'nan'): 1,
#              ('Haiti', 'Govenman Etazini'): 1,
#              ('Huma Abedin', 'Capricia Marshall'): 1,
#              ('Craig Kelly', 'Hillary Clinton'): 3,
#              ('Recos', 'Hillary Clinton'): 1,
#              ('James McGovern', 'nan'): 1,
#              ('Christopher Butzgy', 'Hillary Clinton'): 1,
#              ('Case Button', 'Hillary Clinton'): 1,
#              ('Mike', 'Hillary Clinton'): 2,
#              ('Huma Abedin', 'Kris Balderston'): 1,
#              ('Huma Abedin', 'nan'): 2,
#              ('Huma Abedin', 'Philippe Reines'): 1,
#              ('Judith McHale', 'Doug Hattaway'): 1,
#              ('Esther Brimmer', 'Hillary Clinton'): 1,
#              ('G Wills', 'nan'): 1,
#              ('Lissa Muscatine', 'Cheryl Mills'): 2,
#              ('STATE', 'nan'): 4,
#              ('Megan Rooney', 'Hillary Clinton'): 10,
#              ('Voda Ebeling', 'Hillary Clinton'): 2,
#              ('Jake Sullivan', 'Huma Abedin'): 6,
#              ('Courtney Beale', 'Hillary Clinton'): 2,
#              ('Courtney Beale', 'Jake Sullivan'): 1,
#              ('Judith McHale', 'Carlos Pascual'): 1,
#              ('mchaleja', 'slaughter anne-marie'): 1,
#              ('Cheryl Mills', 'Doug Band'): 1,
#              ('Tomicah Tillemann', 'Hillary Clinton'): 6,
#              ('baldersonkm', 'Hillary Clinton'): 1,
#              ('Judith McHale', 'Philip Crowley'): 1,
#              ('Cheryl Mills', 'Judith McHale'): 1,
#              ('James McGovern', 'Barack Obama'): 1,
#              ('Cheryl Mills', 'Lissa Muscatine'): 1,
#              ('Robert Blake', 'Hillary Clinton'): 1,
#              ('slaughter ann-marie', 'Hillary Clinton'): 1,
#              ('Huma Abedin', 'Lauren Jiloty'): 3,
#              ('Lona Valmoro', 'Lauren Jiloty'): 1,
#              ('Judith McHale', 'Maria Otero'): 1,
#              ('Cheryl Mills', 'LGraham'): 1,
#              ('Maura Pally', 'John Olver'): 1,
#              ('Luis CdeBaca', 'Hillary Clinton'): 1,
#              ('Cheryl Mills', 'Suzanne Grantham'): 1,
#              ('Paul Collier', 'nan'): 1,
#              ('Alex Dupuy', 'nan'): 1,
#              ('Susan Rice', 'Hillary Clinton'): 2,
#              ('Cheryl Mills', 'Michael Posner'): 1,
#              ('Betsy Ebeling', 'Bonnie Klehr'): 1,
#              ('Reines Philippe', 'Hillary Clinton'): 1,
#              ('AP', 'nan'): 1,
#              ('Cheryl Mills', 'Richard Verma'): 2,
#              ('Tsakina Elbegdori', 'Bill Clinton'): 1,
#              ('Lona Valmoro', 'Philippe Reines'): 1,
#              ('Philippe Reines', 'nan'): 1,
#              ('Huma Abedin', 'hanleymr'): 1,
#              ('New York Times', 'nan'): 2,
#              ('millscd', 'Doug Band'): 1,
#              ('Marianne Scott', 'nan'): 1,
#              ('rooneym', 'Hillary Clinton'): 1,
#              ('Huma Abedin', 'Courtney Beale'): 1,
#              ('Robert Russo', 'Betsy Ebeling'): 1,
#              ('Huma Abedin', 'Betsy Ebeling'): 1,
#              ('sullivanjj', 'Philippe Reines'): 1,
#              ('Zachary Iscol', 'Hillary Clinton'): 1,
#              ('Maura Pally', 'Hillary Clinton'): 1,
#              ('Hillary Clinton', 'duk-soo han'): 2,
#              ('Hillary Clinton', 'Kent Conrad'): 2,
#              ('hanleymr', 'Hillary Clinton'): 2,
#              ('Samuel Berger', 'Hillary Clinton'): 4,
#              ('Judith McHale', 'Jacob Lew'): 1,
#              ('Foreign Affairs Magazine', 'nan'): 1,
#              ('nan', 'William Hubbard'): 1,
#              ('Jonathan Prince', 'Hillary Clinton'): 1,
#              ('Jake Sullivan', 'slaughter anne-marie'): 2,
#              ('Lois Quam', 'Hillary Clinton'): 3,
#              ('Jake Sullivan', 'Jacob Lew'): 1,
#              ('Louise Diamond', 'nan'): 2,
#              ('Chester Crocker', 'nan'): 1,
#              ('Cheryl Mills', 'slaughter anne- marie'): 1,
#              ('Huma Abedin', 'slaughter anne-marie'): 4,
#              ('kohhh', 'Hillary Clinton'): 1,
#              ('Joanne Laszczych', 'Hillary Clinton'): 4,
#              ('Harold Hongju Koh', 'Jennifer Robinson'): 1,
#              ('Eric Woodard', 'Hillary Clinton'): 1,
#              ('Daniel Inonye', 'Barack Obama'): 1,
#              ('reines', 'Hillary Clinton'): 1,
#              ('Jake Sullivan', 'Judith McHale'): 2,
#              ('Joshua Daniel', 'Hillary Clinton'): 5,
#              ('Judith Kieffer', 'nan'): 1,
#              ('Jake Sullivan', 'Daniel Schwerin'): 1,
#              ('Hillary Clinton', 'brimmere'): 2,
#              ('American Beverage Association', 'Hillary Clinton'): 1,
#              ('JAMA', 'nan'): 2,
#              ('Hillary Clinton', 'Rajiv Shah'): 1,
#              ('hrod17', 'Cheryl Mills'): 2,
#              ('hrod17', 'Jacob Lew'): 1,
#              ('Hillary Clinton', 'oterom2'): 3,
#              ('Cheryl Mills', 'slaughter anne-marie'): 1,
#              ('aclb', 'Hillary Clinton'): 2,
#              ('Hillary Clinton', 'valenzuelaaa'): 3,
#              ('crowleypj', 'Hillary Clinton'): 2,
#              ('S. Akbar Zaidi', 'nan'): 1,
#              ('Hillary Clinton', 'jjilotylc'): 1,
#              ('Hillary Clinton', 'muscantinel'): 2,
#              ('Maria Calivis', 'Susan Rice'): 1,
#              ('Hillary Clinton', 'mchaleja'): 10,
#              ('Anthony Lake', 'Hillary Clinton'): 1,
#              ('Jeffrey Feltman', 'Jake Sullivan'): 1,
#              ('Hillary Clinton', 'toivnf'): 6,
#              ('Hillary Clinton', 'tillemannts'): 7,
#              ('Madeleine Albright', 'Hillary Clinton'): 1,
#              ('Cheryl Mills', 'Oscar Flores'): 1,
#              ('Heintz', 'nan'): 1,
#              ('Hillary Clinton', 'Hillary Clinton'): 2,
#              ('James Smith', 'Hillary Clinton'): 1,
#              ('Piper Campbell', 'Hillary Clinton'): 1,
#              ('Dana Hyde', 'Hillary Clinton'): 1,
#              ('hrod17', 'oterom2'): 1,
#              ('alcb', 'Hillary Clinton'): 5,
#              ('hrod17', 'Sidney Blumenthal'): 1,
#              ('Hillary Clinton', 'Mark Penn'): 1,
#              ('Chelsea Clinton', 'Bill Clinton'): 2,
#              ('Hillary Clinton', 'bealeca'): 3,
#              ('Hillary Clinton', 'valmmorolj'): 1,
#              ('Hillary Clinton', 'Burns Strider'): 1,
#              ('Jake Sullivan', 'aclb'): 1,
#              ('Hillary Clinton', 'Lynn Forester de Rothschild'): 1,
#              ('latimes.com', 'nan'): 1,
#              ('Monica Hanley', 'Huma Abedin'): 1,
#              ('Cheryl Mills', 'Nora Toiv'): 1,
#              ('David Miliband', 'Hillary Clinton'): 1,
#              ('David Brock', 'nan'): 2,
#              ('Daily Sun', 'nan'): 1,
#              ('Voda Ebeling', 'abedinh'): 1,
#              ('Huma Abedin', 'Voda Ebeling'): 1,
#              ('Neera Tanden', 'Neera Tanden'): 1,
#              ('Cheryl Mills', 'Janice Jacobs'): 1,
#              ('Hillary Clinton', 'Betsy Ebeling'): 1,
#              ('huma', 'abedinh'): 1,
#              ('Opinion Research', 'nan'): 1,
#              ('Hillary Clinton', 'Daniel'): 1})

# %%
# 转换格式 (x, y): weight - > (x, y, weight)
edges_weights = [(key[0], key[1], val) for key, val in edges_weights_temp.items()]
edges_weights
# Out:
# [('Jake Sullivan', 'Hillary Clinton', 815),
#  ('nan', 'Hillary Clinton', 20),
#  ('Cheryl Mills', ';h', 1),
#  ('Cheryl Mills', 'Hillary Clinton', 1182),
#  ('Hillary Clinton', 'Huma Abedin', 32),
#  ('Hillary Clinton', 'russorv', 26),
#  ('slaughter anne-marie', 'Hillary Clinton', 126),
#  ('Harold Hongju Koh', 'Hillary Clinton', 12),
#  ('Wendy Sherman', 'Hillary Clinton', 7),
#  ('Jake Sullivan', 'Wendy Sherman', 1),
#  ('Hillary Clinton', 'sullivanjj', 288),
#  ('Sidney Blumenthal', 'Hillary Clinton', 361),
#  ('Burns Strider', 'Hillary Clinton', 2),
#  ('Huma Abedin', 'Hillary Clinton', 1322),
#  ('Cheryl Mills', 'Cheryl Mills', 17),
#  ('Robert Russo', 'Hillary Clinton', 22),
#  ('Capricia Marshall', 'Cheryl Mills', 2),
#  ('Hillary Clinton', 'Oscar Flores', 5),
#  ('William Burns', 'Hillary Clinton', 10),
#  ('Monica Hanley', 'Hillary Clinton', 24),
#  ('Hillary Clinton', 'abedinh', 345),
#  ('Hillary Clinton', 'millscd', 298),
#  ('Daniel Schwerin', 'Hillary Clinton', 9),
#  ('Hillary Clinton', 'hanleymr', 33),
#  ('Monica Hanley', 'Daniel Schwerin', 1),
#  ('Philippe Reines', 'Thomas Nides', 1),
#  ('Daniel Schwerin', 'Jake Sullivan', 1),
#  ('nan', 'nan', 132),
#  ('Hillary Clinton', 'jilotylc', 226),
#  ('Melanne Verveer', 'Hillary Clinton', 94),
#  ('Hillary Clinton', 'nan', 42),
#  ('Claire Coleman', 'Hillary Clinton', 5),
#  ('Philippe Reines', 'Hillary Clinton', 144),
#  ('Cheryl Mills', 'Jake Sullivan', 7),
#  ('Philippe Reines', 'Cheryl Mills', 1),
#  ('Monica Hanley', 'Jake Sullivan', 1),
#  ('Lona Valmoro', 'Hillary Clinton', 136),
#  ('Hillary Clinton', 'valmorolj', 131),
#  ('Hillary Clinton', 'burnswj', 5),
#  ('Thomas Nides', 'Hillary Clinton', 1),
#  ('Hillary Clinton', 'nidestr', 1),
#  ('Hillary Clinton', 'Jake Sullivan', 15),
#  ('Victoria Nuland', 'Hillary Clinton', 1),
#  ('Maria Otero', 'Hillary Clinton', 9),
#  ('Judith McHale', 'Hillary Clinton', 68),
#  ('Hillary Clinton', 'Michele Flournoy', 1),
#  ('Hillary Clinton', 'Cheryl Mills', 40),
#  ('hrod17', 'Jake Sullivan', 2),
#  ('Alec', 'Cheryl', 1),
#  ('Hillary Clinton', 'Philippe Reines', 49),
#  ('Hillary Clinton', 'Brian Greenspun', 1),
#  ('Hillary Clinton', 'reinesp', 12),
#  ('Hillary Clinton', 'bam', 4),
#  ('Hillary Clinton', 'l', 1),
#  ('hrod17', 'Philippe Reines', 2),
#  ('Hillary Clinton', 'Neera Tanden', 2),
#  ('hrod17', 'valmorolj', 8),
#  ('Hillary Clinton', 'Jacob Lew', 3),
#  ('Hillary Clinton', 'Rick Sloan', 1),
#  ('Hillary Clinton', 'Strobe Talbott', 11),
#  ('Hillary Clinton', 'balderstonkm', 16),
#  ('Hillary Clinton', 'steinbergjb', 8),
#  ('Hillary Clinton', 'William Burns', 2),
#  ('Hillary Clinton', 'mhcaleja', 1),
#  ('Hillary Clinton', 'John Podesta', 2),
#  ('Hillary Clinton', 'sulllivanjj', 4),
#  ('Hillary Clinton', 'Wendy Sherman', 2),
#  ('Hillary Clinton', 'abendinh', 1),
#  ('Hillary Clinton', 'adedinh', 1),
#  ('hrod17', 'nan', 2),
#  ('Hillary Clinton', 'Lissa Muscatine', 7),
#  ('Hillary Clinton', 'muscatinel', 15),
#  ('hrod17', 'muscatinel', 3),
#  ('hrod17', 'sullivanjj', 9),
#  ('hrod17', 'cholletdh', 1),
#  ('hrod17', 'Huma Abedin', 3),
#  ('hrod17', 'Burns Strider', 1),
#  ('Hillary Clinton', 'Jeffrey Farrow', 1),
#  ('Hillary Clinton', 'David Axelrod', 1),
#  ('Hillary Clinton', 'Samuel ("Sandy") Berger', 3),
#  ('Hillary Clinton', 'shapiroa', 6),
#  ('Hillary Clinton', 'david_garten', 2),
#  ('hrod17', 'millscd', 14),
#  ('hrod17', 'reinesp', 1),
#  ('Hillary Clinton', 'verveerms', 9),
#  ('Hillary Clinton', 'kohhh', 3),
#  ('Hillary Clinton', 'lewjj', 7),
#  ('Hillary Clinton', 'Sidney Blumenthal', 49),
#  ('Hillary Clinton', 'Tina Flournoy', 1),
#  ('Hillary Clinton', 'Cherie Blair', 7),
#  ('Hillary Clinton', 'Melanne Verveer', 10),
#  ('Hillary Clinton', 'Jan Piercy', 1),
#  ('Hillary Clinton', 'fuchsmh', 4),
#  ('Hillary Clinton', 'Capricia Marshall', 6),
#  ('Hillary Clinton', 'Terry Duffy', 1),
#  ('hrod17', 'jilotylc', 7),
#  ('Hillary Clinton', 'crowleypj', 10),
#  ('Hillary Clinton', 'campbellkm', 9),
#  ('Hillary Clinton', 'rooneym', 6),
#  ('E. Pelton', 'nan', 1),
#  ('Charles Kiamie', 'nan', 3),
#  ('hrod17', 'abedinh', 5),
#  ('hrod17', 'Scott Gration', 1),
#  ('Hillary Clinton', 'Doug Hattaway', 4),
#  ('Hillary Clinton', 'Nancy Parrish', 1),
#  ('Hillary Clinton', 'kellyc', 3),
#  ('Hillary Clinton', 'holbrookerc', 1),
#  ('hrod17', 'Lisa Caputo', 1),
#  ('hrod17', 'gordonph', 1),
#  ('Hillary Clinton', 'Lisa Caputo', 1),
#  ('Hillary Clinton', 'slaughtera', 29),
#  ('Nicholas Norman', 'nan', 1),
#  ('Hillary Clinton', 'rodriguezme', 4),
#  ('Hillary Clinton', 'Marty Torrey', 2),
#  ('Hillary Clinton', 'Gina Glantz', 1),
#  ('Hillary Clinton', 'Maggie Williams', 3),
#  ('Hillary Clinton', 'hillcr', 1),
#  ('hrod17', 'verveerms', 1),
#  ('Hillary Clinton', 'tauschereo', 3),
#  ('Hillary Clinton', 'feltmanjd', 3),
#  ('Hillary Clinton', 'gordonph', 3),
#  ('hrod17', 'Daniel Baer', 1),
#  ('Hillary Clinton', 'steinbertjb', 1),
#  ('Claire Coleman', 'Cheryl Mills', 1),
#  ('Lauren Jiloty', 'Hillary Clinton', 312),
#  ('millscd', 'Hillary Clinton', 61),
#  ('Cheryl Mills', 'Lourdes Cue', 1),
#  ('Jake Sullivan', 'Cheryl Mills', 4),
#  ('Neera Tanden', 'Hillary Clinton', 6),
#  ('James Steinberg', 'Hillary Clinton', 6),
#  ('Cherie Blair', 'Hillary Clinton', 24),
#  ('Hillary Clinton', 'valmoroli', 1),
#  ('Hillary Clinton', 'vermarr', 27),
#  ('Thomas Shannon', 'Hillary Clinton', 2),
#  ('Lauren Jiloty', 'Huma Abedin', 5),
#  ('Jackie Newmyer', 'Hillary Clinton', 10),
#  ('Barbara Mikulski', 'Hillary Clinton', 11),
#  ('Patrick Kennedy', 'Hillary Clinton', 1),
#  ('nan', 'Hill', 1),
#  ('Robert Danford', 'Hillary Clinton', 1),
#  ('Cheryl Mills', 'Huma Abedin', 13),
#  ('Huma Abedin', 'Cheryl Mills', 5),
#  ('Lissa Muscatine', 'Hillary Clinton', 80),
#  ('NHLA', 'nan', 1),
#  ('Hillary Clinton', 'carsonj', 1),
#  ('Cheryl Mills', 'Capricia Marshall', 1),
#  ('Jacob Lew', 'nan', 1),
#  ('Hillary Clinton', 'shannonta', 1),
#  ('abedinh', 'Hillary Clinton', 46),
#  ('Hillary Clinton', 'Luzzatto', 1),
#  ('Hillary Clinton', 'Daniel Baer', 1),
#  ('Long Term Strategy Group', 'Department of State', 1),
#  ('Hillary Clinton', 'marshallcp', 3),
#  ('millscd', 'Jake Sullivan', 1),
#  ('G. Wills', 'nan', 2),
#  ('reinesp', 'Hillary Clinton', 2),
#  ('Strobe Talbott', 'Hillary Clinton', 35),
#  ('David Johnson', 'Jacob Lew', 2),
#  ('Philippe Reines', 'Jake Sullivan', 3),
#  ('L. Rosenberger', 'nan', 1),
#  ('Lee Brown', 'Karl Eikenberry', 2),
#  ('Lee Feinstein', 'Hillary Clinton', 1),
#  ('Samuel ("Sandy") Berger', 'Hillary Clinton', 8),
#  ('FINCA International', 'nan', 1),
#  ('Huma Abedin', 'Rosemarie Howe', 3),
#  ('Cherie Blair', 'hr15', 1),
#  ('slaughter anne-marie', 'nan', 1),
#  ('valmorolj', 'Hillary Clinton', 5),
#  ('White House', 'nan', 1),
#  ('Jeffrey Farrow', 'Hillary Clinton', 6),
#  ('Jake Sullivan', 'Strobe Talbott', 1),
#  ('Kris Balderston', 'Hillary Clinton', 22),
#  ('Richard Verma', 'Hillary Clinton', 115),
#  ('postmaster', 'Hillary Clinton', 7),
#  ('Colin Powell', 'Hillary Clinton', 1),
#  ('Huma Abedin', 'Donald', 1),
#  ('Cheryl Mills', 'Phillip Crowley', 1),
#  ('Lona Valmoro', 'Huma Abedin', 10),
#  ('Huma Abedin', 'Richard Verma', 2),
#  ('Huma Abedin', 'rosemarie.howe ;h', 1),
#  ('Cheryl Mills', 'Rene Preval', 1),
#  ('hrod17', 'vermarr', 3),
#  ('Huma Abedin', 'Mark Hyman', 2),
#  ('Hillary Clinton', 'hormatsrd', 1),
#  ('Sidney Blumenthal', 'cheryl.mills ;h', 1),
#  ('Cheryl Mills', 'Justin Cooper', 1),
#  ('Oscar Arias Sanchez', 'nan', 1),
#  ('Hillary Clinton', 'sterntd', 3),
#  ('Kurt Campbell', 'Hillary Clinton', 14),
#  ('David Axelrod', 'Hillary Clinton', 2),
#  ('Hillary Clinton', 'abedin', 1),
#  ('John Podesta', 'Hillary Clinton', 2),
#  ('Jake Sullivan', 'Philippe Reines', 7),
#  ('David Garten', 'Hillary Clinton', 1),
#  ('Caroline Adler', 'Hillary Clinton', 2),
#  ('Cheryl Mills', 'Maggie Williams', 2),
#  ('sullivanjj', 'Huma Abedin', 1),
#  ('Huma Abedin', 'Lona Valmoro', 2),
#  ('Huma Abedin', 'Jake Sullivan', 7),
#  ('bam', 'Hillary Clinton', 1),
#  ('Hillary Clinton', 'posnermh', 1),
#  ('Cheryl Mills', 'nan', 3),
#  ('muscatinel', 'Hillary Clinton', 1),
#  ('abedinh', 'rrh.interiors', 1),
#  ('Hillary Clinton', 'Council on Foreign Relations', 1),
#  ('Sidney Blumenthal', 'Cheryl Mills', 1),
#  ('Cheryl Mills', 'Jacob Lew', 3),
#  ('111th Congress', 'nan', 1),
#  ('Hillary Clinton', 'schwerindb', 1),
#  ('Huma Abedin', 'mh.interiors', 1),
#  ('Cheryl Mills', 'Jim Kennedy', 1),
#  ('Cheryl Mills', 'Samuel ("Sandy") Berger', 1),
#  ('Cheryl Mills', 'Strobe Talbott', 1),
#  ('sullivanjj', 'Hillary Clinton', 22),
#  ('abedinh', 'Cheryl Mills', 2),
#  ('nan', 'Biography', 1),
#  ('Andrew Shapiro', 'Hillary Clinton', 7),
#  ('verveerms', 'Hillary Clinton', 1),
#  ('Derek Chollet', 'Hillary Clinton', 1),
#  ('Jeffrey Farrow', 'Jake Sullivan', 4),
#  ('reines philippe ', 'Hillary Clinton', 1),
#  ('Thomas Donilon', 'Hillary Clinton', 1),
#  ('Jacob Lew', 'Hillary Clinton', 12),
#  ('G. Lou de Bac', 'Cheryl Mills', 1),
#  ('Huma Abedin', 'Huma Abedin', 1),
#  ('Laurie Rubiner', 'Hillary Clinton', 1),
#  ('Huma Abedin', 'Laurie Rubiner', 1),
#  ('verveerms', 'Huma Abedin', 1),
#  ('Huma Abedin', 'Oscar Flores', 12),
#  ('Danielle Brian', 'Hillary Clinton', 2),
#  ('Strobe Talbott', 'nan', 1),
#  ('Werner Ilic', 'Kabul LGF Request', 1),
#  ('nan', 'Sir', 1),
#  ('crowleypj', 'h;preines', 2),
#  ('Jeffrey Feltman', 'Hillary Clinton', 13),
#  ('PVervee', 'Hillary Clinton', 1),
#  ('Philip Crowley', 'Hillary Clinton', 15),
#  ('George Mitchell', 'Hillary Clinton', 6),
#  ('AGNA USEMB Kabul Afghanistan', 'nan', 1),
#  ('Huma Abedin', 'valmorolj', 5),
#  ('Philippe Reines', 'Huma Abedin', 1),
#  ('Huma Abedin', 'jilotylc', 1),
#  ('J. Finkle', 'nan', 1),
#  ('Capricia Marshall', 'Hillary Clinton', 12),
#  ('Capricia Marshall', 'Huma Abedin', 1),
#  ('Michael Fuchs', 'Hillary Clinton', 15),
#  ('Capricia Marshall', 'abedin huma; h', 2),
#  ('Hillary Clinton', 'ki-moon ban', 1),
#  ('Prime Minister', 'Peter Robinson', 1),
#  ('Ian Kelly', 'nan', 1),
#  ('STATE', 'ASUNCION', 1),
#  ('STATE', 'WHADP', 1),
#  ('Lissa Muscatine', 'Huma Abedin', 1),
#  ('Sidney Blumenthal', 'nan', 11),
#  ('Eni Faleomavaega', 'nan', 1),
#  ('Cheryl Mills', 'Lona Valmoro', 1),
#  ('Lona Valmoro', 'Cheryl Mills', 1),
#  ('Susan Rice', 'nan', 1),
#  ('Paul Jones', 'Hillary Clinton', 2),
#  ('Philip Gordon', 'Hillary Clinton', 4),
#  ('h; mills cheryl d', 'Kris Balderston', 1),
#  ('Philippe Reines', 'Philip Crowley', 1),
#  ('Miguel Rodriguez', 'Hillary Clinton', 10),
#  ('Christopher Hill', 'Hillary Clinton', 1),
#  ('politico - drew elizabeth', 'nan', 1),
#  ('Cheryl Mills', 'Lauren Jiloty', 1),
#  ('Lauren Jiloty', 'Cheryl Mills', 3),
#  ('U.S. Global Leadership Coalition', 'nan', 1),
#  ('M. Albright', 'Hillary Clinton', 1),
#  ('Max Baucus', 'Hillary Clinton', 1),
#  ('Linda Dewan', 'Hillary Clinton', 1),
#  ('jilotylc', 'Hillary Clinton', 21),
#  ('Ellen Tauscher', 'Hillary Clinton', 9),
#  ('Gina Glantz', 'Hillary Clinton', 2),
#  ('Voda Ebeling', 'Lauren Jiloty', 1),
#  ('Patrick Kennedy', 'nan', 1),
#  ('Arturo Valenzuela', 'Hillary Clinton', 7),
#  ('Nora Tov', 'Hillary Clinton', 1),
#  ('Philippe Reines', 'Diane Reynolds', 2),
#  ('Huma Abedin', 'Luzzatto', 1),
#  ('Daniel Baer', 'Hillary Clinton', 5),
#  ('SRGIA', 'nan', 1),
#  ('Jeffrey Feltman', 'Harold Hongju Koh', 2),
#  ('Harold Hongju Koh', 'Jeffrey Feltman', 1),
#  ('Reta Jo Lewis', 'Hillary Clinton', 1),
#  ('Johnnie Carson', 'Hillary Clinton', 1),
#  ('sullivan jj', 'Hillary Clinton', 2),
#  ('Huma Abedin', 'sullivanjj', 1),
#  ('muscatinel', 'Daniel Baer', 1),
#  ('Nora Toiv', 'Hillary Clinton', 5),
#  ('KPK', 'Hillary Clinton', 1),
#  ('Robert Russo', 'Doug Hattaway', 1),
#  ('Cheryl Mills', 'Christopher Edwards', 1),
#  ('Cheryl Mills', 'Maura Pally', 1),
#  ('mchaleja', 'Hillary Clinton', 3),
#  ('millscd', 'Nora Toiv', 1),
#  ('Todd Stern', 'Hillary Clinton', 5),
#  ('Jake Sullivan', 'preines; h', 1),
#  ('Philippe Reines', 'sullivan jake; h', 1),
#  ('vermarr', 'Hillary Clinton', 2),
#  ('Huma Abedin', 'preines; h', 1),
#  ('Rajiv Shah', 'Hillary Clinton', 1),
#  ('Judith McHale', 'Lona Valmoro', 1),
#  ('Huma Abedin', 'Oscar Lores', 1),
#  ('Christopher Green', 'nan', 1),
#  ('Robert Hormats', 'Hillary Clinton', 1),
#  ('Chad Weston', 'nan', 1),
#  ('Strobe Talbott', 'Huma Abedin', 1),
#  ('valmorolj', 'Huma Abedin', 1),
#  ('Michael Posner', 'Hillary Clinton', 1),
#  ('Cecile Richards', 'nan', 1),
#  ('Philip Crowley', 'Michael Posner', 1),
#  ('Andrew Mayock', 'nan', 1),
#  ('Washington Post', 'nan', 4),
#  ('Jim Hoagland', 'nan', 1),
#  ('Tomicah Tillemann', 'nan', 1),
#  ('slaughtera', 'Hillary Clinton', 3),
#  ('lewjj', 'Hillary Clinton', 1),
#  ('Haiti', 'United States of America', 3),
#  ('nan', "etats-unis d'amerique", 1),
#  ('Haiti', "etat-unis d'amerique", 1),
#  ('Huma Abedin', 'Justin Cooper', 1),
#  ('Jake Sullivan', 'Philip Crowley', 1),
#  ('Jake Sullivan', 'Richard Verma', 2),
#  ('Cheryl Mills', 'Michele Bond', 1),
#  ('vermarr', 'Jake Sullivan', 1),
#  ('Betsy Ebeling', 'Hillary Clinton', 30),
#  ('Payton Knopf', 'nan', 1),
#  ('Haiti', 'Govenman Etazini', 1),
#  ('Huma Abedin', 'Capricia Marshall', 1),
#  ('Craig Kelly', 'Hillary Clinton', 3),
#  ('Recos', 'Hillary Clinton', 1),
#  ('James McGovern', 'nan', 1),
#  ('Christopher Butzgy', 'Hillary Clinton', 1),
#  ('Case Button', 'Hillary Clinton', 1),
#  ('Mike', 'Hillary Clinton', 2),
#  ('Huma Abedin', 'Kris Balderston', 1),
#  ('Huma Abedin', 'nan', 2),
#  ('Huma Abedin', 'Philippe Reines', 1),
#  ('Judith McHale', 'Doug Hattaway', 1),
#  ('Esther Brimmer', 'Hillary Clinton', 1),
#  ('G Wills', 'nan', 1),
#  ('Lissa Muscatine', 'Cheryl Mills', 2),
#  ('STATE', 'nan', 4),
#  ('Megan Rooney', 'Hillary Clinton', 10),
#  ('Voda Ebeling', 'Hillary Clinton', 2),
#  ('Jake Sullivan', 'Huma Abedin', 6),
#  ('Courtney Beale', 'Hillary Clinton', 2),
#  ('Courtney Beale', 'Jake Sullivan', 1),
#  ('Judith McHale', 'Carlos Pascual', 1),
#  ('mchaleja', 'slaughter anne-marie', 1),
#  ('Cheryl Mills', 'Doug Band', 1),
#  ('Tomicah Tillemann', 'Hillary Clinton', 6),
#  ('baldersonkm', 'Hillary Clinton', 1),
#  ('Judith McHale', 'Philip Crowley', 1),
#  ('Cheryl Mills', 'Judith McHale', 1),
#  ('James McGovern', 'Barack Obama', 1),
#  ('Cheryl Mills', 'Lissa Muscatine', 1),
#  ('Robert Blake', 'Hillary Clinton', 1),
#  ('slaughter ann-marie', 'Hillary Clinton', 1),
#  ('Huma Abedin', 'Lauren Jiloty', 3),
#  ('Lona Valmoro', 'Lauren Jiloty', 1),
#  ('Judith McHale', 'Maria Otero', 1),
#  ('Cheryl Mills', 'LGraham', 1),
#  ('Maura Pally', 'John Olver', 1),
#  ('Luis CdeBaca', 'Hillary Clinton', 1),
#  ('Cheryl Mills', 'Suzanne Grantham', 1),
#  ('Paul Collier', 'nan', 1),
#  ('Alex Dupuy', 'nan', 1),
#  ('Susan Rice', 'Hillary Clinton', 2),
#  ('Cheryl Mills', 'Michael Posner', 1),
#  ('Betsy Ebeling', 'Bonnie Klehr', 1),
#  ('Reines Philippe', 'Hillary Clinton', 1),
#  ('AP', 'nan', 1),
#  ('Cheryl Mills', 'Richard Verma', 2),
#  ('Tsakina Elbegdori', 'Bill Clinton', 1),
#  ('Lona Valmoro', 'Philippe Reines', 1),
#  ('Philippe Reines', 'nan', 1),
#  ('Huma Abedin', 'hanleymr', 1),
#  ('New York Times', 'nan', 2),
#  ('millscd', 'Doug Band', 1),
#  ('Marianne Scott', 'nan', 1),
#  ('rooneym', 'Hillary Clinton', 1),
#  ('Huma Abedin', 'Courtney Beale', 1),
#  ('Robert Russo', 'Betsy Ebeling', 1),
#  ('Huma Abedin', 'Betsy Ebeling', 1),
#  ('sullivanjj', 'Philippe Reines', 1),
#  ('Zachary Iscol', 'Hillary Clinton', 1),
#  ('Maura Pally', 'Hillary Clinton', 1),
#  ('Hillary Clinton', 'duk-soo han', 2),
#  ('Hillary Clinton', 'Kent Conrad', 2),
#  ('hanleymr', 'Hillary Clinton', 2),
#  ('Samuel Berger', 'Hillary Clinton', 4),
#  ('Judith McHale', 'Jacob Lew', 1),
#  ('Foreign Affairs Magazine', 'nan', 1),
#  ('nan', 'William Hubbard', 1),
#  ('Jonathan Prince', 'Hillary Clinton', 1),
#  ('Jake Sullivan', 'slaughter anne-marie', 2),
#  ('Lois Quam', 'Hillary Clinton', 3),
#  ('Jake Sullivan', 'Jacob Lew', 1),
#  ('Louise Diamond', 'nan', 2),
#  ('Chester Crocker', 'nan', 1),
#  ('Cheryl Mills', 'slaughter anne- marie', 1),
#  ('Huma Abedin', 'slaughter anne-marie', 4),
#  ('kohhh', 'Hillary Clinton', 1),
#  ('Joanne Laszczych', 'Hillary Clinton', 4),
#  ('Harold Hongju Koh', 'Jennifer Robinson', 1),
#  ('Eric Woodard', 'Hillary Clinton', 1),
#  ('Daniel Inonye', 'Barack Obama', 1),
#  ('reines', 'Hillary Clinton', 1),
#  ('Jake Sullivan', 'Judith McHale', 2),
#  ('Joshua Daniel', 'Hillary Clinton', 5),
#  ('Judith Kieffer', 'nan', 1),
#  ('Jake Sullivan', 'Daniel Schwerin', 1),
#  ('Hillary Clinton', 'brimmere', 2),
#  ('American Beverage Association', 'Hillary Clinton', 1),
#  ('JAMA', 'nan', 2),
#  ('Hillary Clinton', 'Rajiv Shah', 1),
#  ('hrod17', 'Cheryl Mills', 2),
#  ('hrod17', 'Jacob Lew', 1),
#  ('Hillary Clinton', 'oterom2', 3),
#  ('Cheryl Mills', 'slaughter anne-marie', 1),
#  ('aclb', 'Hillary Clinton', 2),
#  ('Hillary Clinton', 'valenzuelaaa', 3),
#  ('crowleypj', 'Hillary Clinton', 2),
#  ('S. Akbar Zaidi', 'nan', 1),
#  ('Hillary Clinton', 'jjilotylc', 1),
#  ('Hillary Clinton', 'muscantinel', 2),
#  ('Maria Calivis', 'Susan Rice', 1),
#  ('Hillary Clinton', 'mchaleja', 10),
#  ('Anthony Lake', 'Hillary Clinton', 1),
#  ('Jeffrey Feltman', 'Jake Sullivan', 1),
#  ('Hillary Clinton', 'toivnf', 6),
#  ('Hillary Clinton', 'tillemannts', 7),
#  ('Madeleine Albright', 'Hillary Clinton', 1),
#  ('Cheryl Mills', 'Oscar Flores', 1),
#  ('Heintz', 'nan', 1),
#  ('Hillary Clinton', 'Hillary Clinton', 2),
#  ('James Smith', 'Hillary Clinton', 1),
#  ('Piper Campbell', 'Hillary Clinton', 1),
#  ('Dana Hyde', 'Hillary Clinton', 1),
#  ('hrod17', 'oterom2', 1),
#  ('alcb', 'Hillary Clinton', 5),
#  ('hrod17', 'Sidney Blumenthal', 1),
#  ('Hillary Clinton', 'Mark Penn', 1),
#  ('Chelsea Clinton', 'Bill Clinton', 2),
#  ('Hillary Clinton', 'bealeca', 3),
#  ('Hillary Clinton', 'valmmorolj', 1),
#  ('Hillary Clinton', 'Burns Strider', 1),
#  ('Jake Sullivan', 'aclb', 1),
#  ('Hillary Clinton', 'Lynn Forester de Rothschild', 1),
#  ('latimes.com', 'nan', 1),
#  ('Monica Hanley', 'Huma Abedin', 1),
#  ('Cheryl Mills', 'Nora Toiv', 1),
#  ('David Miliband', 'Hillary Clinton', 1),
#  ('David Brock', 'nan', 2),
#  ('Daily Sun', 'nan', 1),
#  ('Voda Ebeling', 'abedinh', 1),
#  ('Huma Abedin', 'Voda Ebeling', 1),
#  ('Neera Tanden', 'Neera Tanden', 1),
#  ('Cheryl Mills', 'Janice Jacobs', 1),
#  ('Hillary Clinton', 'Betsy Ebeling', 1),
#  ('huma', 'abedinh', 1),
#  ('Opinion Research', 'nan', 1),
#  ('Hillary Clinton', 'Daniel', 1)]

# %%
# 创建一个有向图
graph = nx.DiGraph()
# 设置有向图中的路径以及权重
graph.add_weighted_edges_from(edges_weights)
pagerank = nx.pagerank(graph)
pagerank
# Out:
# {'Jake Sullivan': 0.005791704166582624,
#  'Hillary Clinton': 0.30625575336382416,
#  'nan': 0.13999227061446815,
#  'Cheryl Mills': 0.009358382485728864,
#  ';h': 0.0008967850871949974,
#  'Huma Abedin': 0.010664457957706461,
#  'russorv': 0.004414888802206403,
#  'slaughter anne-marie': 0.001411729861610798,
#  'Harold Hongju Koh': 0.0009914506387867286,
#  'Wendy Sherman': 0.0011673799493548969,
#  'sullivanjj': 0.040032942578700645,
#  'Sidney Blumenthal': 0.007543328643239068,
#  'Burns Strider': 0.0010366588039860962,
#  'Robert Russo': 0.0008904426392777106,
#  'Capricia Marshall': 0.0017166548334911842,
#  'Oscar Flores': 0.0016529953921252999,
#  'William Burns': 0.0011615538825799176,
#  'Monica Hanley': 0.0008904426392777106,
#  'abedinh': 0.04865794676080488,
#  'millscd': 0.04143526549410853,
#  'Daniel Schwerin': 0.0009243019859440611,
#  'hanleymr': 0.005370314170153694,
#  'Philippe Reines': 0.009023759500896596,
#  'Thomas Nides': 0.0009399158462110825,
#  'jilotylc': 0.03160717295021766,
#  'Melanne Verveer': 0.002245998855788746,
#  'Claire Coleman': 0.0008904426392777106,
#  'Lona Valmoro': 0.0009202921825250339,
#  'valmorolj': 0.01876619350197836,
#  'burnswj': 0.0015682207475332284,
#  'nidestr': 0.0010259982609288141,
#  'Victoria Nuland': 0.0008904426392777106,
#  'Maria Otero': 0.0009008777018286163,
#  'Judith McHale': 0.0009084372207449556,
#  'Michele Flournoy': 0.0010259982609288141,
#  'hrod17': 0.0008904426392777106,
#  'Alec': 0.0008904426392777106,
#  'Cheryl': 0.0016473411963447374,
#  'Brian Greenspun': 0.0010259982609288141,
#  'reinesp': 0.0025277706421482356,
#  'bam': 0.0014326651258821249,
#  'l': 0.0010259982609288141,
#  'Neera Tanden': 0.0013220821647246697,
#  'Jacob Lew': 0.0020999570774330755,
#  'Rick Sloan': 0.0010259982609288141,
#  'Strobe Talbott': 0.0023937229921321156,
#  'balderstonkm': 0.0030593325856953677,
#  'steinbergjb': 0.001974887612486539,
#  'mhcaleja': 0.0010259982609288141,
#  'John Podesta': 0.0011615538825799176,
#  'sulllivanjj': 0.0014326651258821249,
#  'abendinh': 0.0010259982609288141,
#  'adedinh': 0.0010259982609288141,
#  'Lissa Muscatine': 0.0018456744387527224,
#  'muscatinel': 0.00295575859321611,
#  'cholletdh': 0.0009011031823349927,
#  'Jeffrey Farrow': 0.0010259982609288141,
#  'David Axelrod': 0.0010259982609288141,
#  'Samuel ("Sandy") Berger': 0.001303451952148308,
#  'shapiroa': 0.0017037763691843321,
#  'david_garten': 0.0011615538825799176,
#  'verveerms': 0.002121103777194925,
#  'kohhh': 0.0012971095042310214,
#  'lewjj': 0.0018393319908354357,
#  'Tina Flournoy': 0.0010259982609288141,
#  'Cherie Blair': 0.0018393319908354357,
#  'Jan Piercy': 0.0010259982609288141,
#  'fuchsmh': 0.0014326651258821249,
#  'Terry Duffy': 0.0010259982609288141,
#  'crowleypj': 0.002245998855788746,
#  'campbellkm': 0.0021104432341376425,
#  'rooneym': 0.0017037763691843321,
#  'E. Pelton': 0.0008904426392777106,
#  'Charles Kiamie': 0.0008904426392777106,
#  'Scott Gration': 0.0009011031823349927,
#  'Doug Hattaway': 0.0014746376283108235,
#  'Nancy Parrish': 0.0010259982609288141,
#  'kellyc': 0.0012971095042310214,
#  'holbrookerc': 0.0010259982609288141,
#  'Lisa Caputo': 0.0010366588039860962,
#  'gordonph': 0.0013077700472883035,
#  'slaughtera': 0.0048215556671597146,
#  'Nicholas Norman': 0.0008904426392777106,
#  'rodriguezme': 0.0014326651258821249,
#  'Marty Torrey': 0.0011615538825799176,
#  'Gina Glantz': 0.0010259982609288141,
#  'Maggie Williams': 0.0013097944000655948,
#  'hillcr': 0.0010259982609288141,
#  'tauschereo': 0.0012971095042310214,
#  'feltmanjd': 0.0012971095042310214,
#  'Daniel Baer': 0.0022924715181031814,
#  'steinbertjb': 0.0010259982609288141,
#  'Lauren Jiloty': 0.001112256650240778,
#  'Lourdes Cue': 0.0008967850871949974,
#  'James Steinberg': 0.0008904426392777106,
#  'valmoroli': 0.0010259982609288141,
#  'vermarr': 0.004582426053029353,
#  'Thomas Shannon': 0.0008904426392777106,
#  'Jackie Newmyer': 0.0008904426392777106,
#  'Barbara Mikulski': 0.0008904426392777106,
#  'Patrick Kennedy': 0.0008904426392777106,
#  'Hill': 0.0016483680937244439,
#  'Robert Danford': 0.0008904426392777106,
#  'NHLA': 0.0008904426392777106,
#  'carsonj': 0.0010259982609288141,
#  'shannonta': 0.0010259982609288141,
#  'Luzzatto': 0.0010325342773183795,
#  'Long Term Strategy Group': 0.0008904426392777106,
#  'Department of State': 0.0016473411963447374,
#  'marshallcp': 0.0012971095042310214,
#  'G. Wills': 0.0008904426392777106,
#  'David Johnson': 0.0008904426392777106,
#  'L. Rosenberger': 0.0008904426392777106,
#  'Lee Brown': 0.0008904426392777106,
#  'Karl Eikenberry': 0.0016473411963447374,
#  'Lee Feinstein': 0.0008904426392777106,
#  'FINCA International': 0.0008904426392777106,
#  'Rosemarie Howe': 0.0009100506884464068,
#  'hr15': 0.000952966062396964,
#  'White House': 0.0008904426392777106,
#  'Kris Balderston': 0.001653877212734303,
#  'Richard Verma': 0.0009278517014413731,
#  'postmaster': 0.0008904426392777106,
#  'Colin Powell': 0.0008904426392777106,
#  'Donald': 0.000896978655667276,
#  'Phillip Crowley': 0.0008967850871949974,
#  'rosemarie.howe ;h': 0.000896978655667276,
#  'Rene Preval': 0.0008967850871949974,
#  'Mark Hyman': 0.0009035146720568414,
#  'hormatsrd': 0.0010259982609288141,
#  'cheryl.mills ;h': 0.000907579721599746,
#  'Justin Cooper': 0.0009033211035845628,
#  'Oscar Arias Sanchez': 0.0008904426392777106,
#  'sterntd': 0.0012971095042310214,
#  'Kurt Campbell': 0.0008904426392777106,
#  'abedin': 0.0010259982609288141,
#  'David Garten': 0.0008904426392777106,
#  'Caroline Adler': 0.0008904426392777106,
#  'posnermh': 0.0010259982609288141,
#  'rrh.interiors': 0.0017341377216634813,
#  'Council on Foreign Relations': 0.0010259982609288141,
#  '111th Congress': 0.0008904426392777106,
#  'schwerindb': 0.0010259982609288141,
#  'mh.interiors': 0.000896978655667276,
#  'Jim Kennedy': 0.0008967850871949974,
#  'Biography': 0.0016483680937244439,
#  'Andrew Shapiro': 0.0008904426392777106,
#  'Derek Chollet': 0.0008904426392777106,
#  'reines philippe ': 0.0008904426392777106,
#  'Thomas Donilon': 0.0008904426392777106,
#  'G. Lou de Bac': 0.0008904426392777106,
#  'Laurie Rubiner': 0.000896978655667276,
#  'Danielle Brian': 0.0008904426392777106,
#  'Werner Ilic': 0.0008904426392777106,
#  'Kabul LGF Request': 0.0016473411963447374,
#  'Sir': 0.0016483680937244439,
#  'h;preines': 0.0018447397898928722,
#  'Jeffrey Feltman': 0.000950639228209635,
#  'PVervee': 0.0008904426392777106,
#  'Philip Crowley': 0.0009561769755369673,
#  'George Mitchell': 0.0008904426392777106,
#  'AGNA USEMB Kabul Afghanistan': 0.0008904426392777106,
#  'J. Finkle': 0.0008904426392777106,
#  'Michael Fuchs': 0.0008904426392777106,
#  'abedin huma; h': 0.0010620735891054367,
#  'ki-moon ban': 0.0010259982609288141,
#  'Prime Minister': 0.0008904426392777106,
#  'Peter Robinson': 0.0016473411963447374,
#  'Ian Kelly': 0.0008904426392777106,
#  'STATE': 0.0008904426392777106,
#  'ASUNCION': 0.0010165923987888817,
#  'WHADP': 0.0010165923987888817,
#  'Eni Faleomavaega': 0.0008904426392777106,
#  'Susan Rice': 0.0016473411963447374,
#  'Paul Jones': 0.0008904426392777106,
#  'Philip Gordon': 0.0008904426392777106,
#  'h; mills cheryl d': 0.0008904426392777106,
#  'Miguel Rodriguez': 0.0008904426392777106,
#  'Christopher Hill': 0.0008904426392777106,
#  'politico - drew elizabeth': 0.0008904426392777106,
#  'U.S. Global Leadership Coalition': 0.0008904426392777106,
#  'M. Albright': 0.0008904426392777106,
#  'Max Baucus': 0.0008904426392777106,
#  'Linda Dewan': 0.0008904426392777106,
#  'Ellen Tauscher': 0.0008904426392777106,
#  'Voda Ebeling': 0.000896978655667276,
#  'Arturo Valenzuela': 0.0008904426392777106,
#  'Nora Tov': 0.0008904426392777106,
#  'Diane Reynolds': 0.0009893890531444544,
#  'SRGIA': 0.0008904426392777106,
#  'Reta Jo Lewis': 0.0008904426392777106,
#  'Johnnie Carson': 0.0008904426392777106,
#  'sullivan jj': 0.0008904426392777106,
#  'Nora Toiv': 0.0014468520703632814,
#  'KPK': 0.0008904426392777106,
#  'Christopher Edwards': 0.0008967850871949974,
#  'Maura Pally': 0.0008967850871949974,
#  'mchaleja': 0.002245998855788746,
#  'Todd Stern': 0.0008904426392777106,
#  'preines; h': 0.0009028047224422551,
#  'sullivan jake; h': 0.0009399158462110825,
#  'Rajiv Shah': 0.0010259982609288141,
#  'Oscar Lores': 0.000896978655667276,
#  'Christopher Green': 0.0008904426392777106,
#  'Robert Hormats': 0.0008904426392777106,
#  'Chad Weston': 0.0008904426392777106,
#  'Michael Posner': 0.0009475841732223895,
#  'Cecile Richards': 0.0008904426392777106,
#  'Andrew Mayock': 0.0008904426392777106,
#  'Washington Post': 0.0008904426392777106,
#  'Jim Hoagland': 0.0008904426392777106,
#  'Tomicah Tillemann': 0.0008904426392777106,
#  'Haiti': 0.0008904426392777106,
#  'United States of America': 0.0013445817735179269,
#  "etats-unis d'amerique": 0.0016483680937244439,
#  "etat-unis d'amerique": 0.0010418223506911159,
#  'Michele Bond': 0.0008967850871949974,
#  'Betsy Ebeling': 0.0010640717171961724,
#  'Payton Knopf': 0.0008904426392777106,
#  'Govenman Etazini': 0.0010418223506911159,
#  'Craig Kelly': 0.0008904426392777106,
#  'Recos': 0.0008904426392777106,
#  'James McGovern': 0.0008904426392777106,
#  'Christopher Butzgy': 0.0008904426392777106,
#  'Case Button': 0.0008904426392777106,
#  'Mike': 0.0008904426392777106,
#  'Esther Brimmer': 0.0008904426392777106,
#  'G Wills': 0.0008904426392777106,
#  'Megan Rooney': 0.0008904426392777106,
#  'Courtney Beale': 0.000896978655667276,
#  'Carlos Pascual': 0.0009008777018286163,
#  'Doug Band': 0.0014468520703632814,
#  'baldersonkm': 0.0008904426392777106,
#  'Barack Obama': 0.002025790474878251,
#  'Robert Blake': 0.0008904426392777106,
#  'slaughter ann-marie': 0.0008904426392777106,
#  'LGraham': 0.0008967850871949974,
#  'John Olver': 0.0012715879722441027,
#  'Luis CdeBaca': 0.0008904426392777106,
#  'Suzanne Grantham': 0.0008967850871949974,
#  'Paul Collier': 0.0008904426392777106,
#  'Alex Dupuy': 0.0008904426392777106,
#  'Bonnie Klehr': 0.000919617761932653,
#  'Reines Philippe': 0.0008904426392777106,
#  'AP': 0.0008904426392777106,
#  'Tsakina Elbegdori': 0.0008904426392777106,
#  'Bill Clinton': 0.0024042397534117643,
#  'New York Times': 0.0008904426392777106,
#  'Marianne Scott': 0.0008904426392777106,
#  'Zachary Iscol': 0.0008904426392777106,
#  'duk-soo han': 0.0011615538825799176,
#  'Kent Conrad': 0.0011615538825799176,
#  'Samuel Berger': 0.0008904426392777106,
#  'Foreign Affairs Magazine': 0.0008904426392777106,
#  'William Hubbard': 0.0016483680937244439,
#  'Jonathan Prince': 0.0008904426392777106,
#  'Lois Quam': 0.0008904426392777106,
#  'Louise Diamond': 0.0008904426392777106,
#  'Chester Crocker': 0.0008904426392777106,
#  'slaughter anne- marie': 0.0008967850871949974,
#  'Joanne Laszczych': 0.0008904426392777106,
#  'Jennifer Robinson': 0.000950639228209635,
#  'Eric Woodard': 0.0008904426392777106,
#  'Daniel Inonye': 0.0008904426392777106,
#  'reines': 0.0008904426392777106,
#  'Joshua Daniel': 0.0008904426392777106,
#  'Judith Kieffer': 0.0008904426392777106,
#  'brimmere': 0.0011615538825799176,
#  'American Beverage Association': 0.0008904426392777106,
#  'JAMA': 0.0008904426392777106,
#  'oterom2': 0.0013077700472883035,
#  'aclb': 0.0008962687060526897,
#  'valenzuelaaa': 0.0012971095042310214,
#  'S. Akbar Zaidi': 0.0008904426392777106,
#  'jjilotylc': 0.0010259982609288141,
#  'muscantinel': 0.0011615538825799176,
#  'Maria Calivis': 0.0008904426392777106,
#  'Anthony Lake': 0.0008904426392777106,
#  'toivnf': 0.0017037763691843321,
#  'tillemannts': 0.0018393319908354357,
#  'Madeleine Albright': 0.0008904426392777106,
#  'Heintz': 0.0008904426392777106,
#  'James Smith': 0.0008904426392777106,
#  'Piper Campbell': 0.0008904426392777106,
#  'Dana Hyde': 0.0008904426392777106,
#  'alcb': 0.0008904426392777106,
#  'Mark Penn': 0.0010259982609288141,
#  'Chelsea Clinton': 0.0008904426392777106,
#  'bealeca': 0.0012971095042310214,
#  'valmmorolj': 0.0010259982609288141,
#  'Lynn Forester de Rothschild': 0.0010259982609288141,
#  'latimes.com': 0.0008904426392777106,
#  'David Miliband': 0.0008904426392777106,
#  'David Brock': 0.0008904426392777106,
#  'Daily Sun': 0.0008904426392777106,
#  'Janice Jacobs': 0.0008967850871949974,
#  'huma': 0.0008904426392777106,
#  'Opinion Research': 0.0008904426392777106,
#  'Daniel': 0.0010259982609288141}

# %%
# 计算每个节点的pagerank数值
pagerank_list = {node:rank for node, rank in pagerank.items()}

# %%
nx.set_node_attributes(graph, name='pagerank', values=pagerank)

# %%
show_graph(graph)

# %%
# 精简上图，设置PR值筛选大于阈值的重要核心节点
pagerank_threshold = 0.005
small_graph = graph.copy()
for n, p_rank in graph.nodes(data=True):
    if p_rank['pagerank'] < pagerank_threshold:
        small_graph.remove_node(n)
show_graph(small_graph, 'circular_layout')
